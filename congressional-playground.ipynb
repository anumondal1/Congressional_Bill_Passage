# %% [markdown]
# # Congressional Playground

# %% [markdown]
# ## Background Documentation

# %% [markdown]
# ### Bills and Resolutions
#
# In the context of the United States Congress, bills and resolutions are both legislative proposals, but they serve different purposes and have different effects if passed.
#
# 1. **Bills**:
#    - A bill is a proposal for a new law or an amendment to an existing law.
#    - Bills can be introduced in either the House of Representatives or the Senate.
#    - There are two main types of bills: public bills and private bills.
#      - Public bills apply to the general public or to the whole country and address matters of national concern.
#      - Private bills deal with individual matters, such as claims against the government or immigration issues.
#    - Once introduced, a bill goes through several stages of consideration, including committee review, debate, and voting in both chambers of Congress.
#    - If a bill is approved by both the House and the Senate in identical form, it is sent to the President for approval. If signed by the President, it becomes law.
#
# 2. **Resolutions**:
#    - A resolution is a formal expression of the opinion, will, or intent of one or both chambers of Congress.
#    - Unlike bills, resolutions do not have the force of law and do not require the President's signature.
#    - There are several types of resolutions, including:
#      - Simple resolutions: These are passed by either the House or the Senate to address matters that affect only that chamber.
#      - Concurrent resolutions: These are passed by both the House and the Senate to express the sentiments of both chambers. They are often used to establish joint committees or to convey congratulations or condolences.
#      - Joint resolutions: These are similar to bills and have the force of law if approved by both chambers and signed by the President. They are typically used for specific and temporary purposes, such as proposing constitutional amendments or authorizing military action.
#
# In summary, while both bills and resolutions are legislative proposals, bills have the potential to become law and address substantive policy matters, while resolutions express the views or intentions of Congress on various issues without having the force of law.
#
# <font color="#900">*Let's only consider bills*</font>

# %% [markdown]
# ## Overview
#
# I have a few examples of accessing bill information from two different end points (GovInfo and Congress).
#
# I have not decided which one I prefer, but I am leaning towards the one specifically for Congress.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Install modules

# %%
if True:
  # !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.40.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.7.0

# %% [markdown]
# ### Imports

# %%
import requests
import json
import sys
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import os
from IPython.display import display_markdown
from google.colab import drive
import numpy as np

# Google Collab Goodies
from IPython.display import display_markdown
from google.colab import data_table
data_table.enable_dataframe_formatter()
from google.colab import drive

import pyarrow.parquet as pq
from urllib.parse import urlparse, parse_qs
import copy
os.environ["HF_TOKEN"] = "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"

# %%
## From Wesley

import pandas as pd
from sentence_transformers import SentenceTransformer
from tensorflow.keras.layers import Input, LSTM, Dense, Reshape, Concatenate
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import tensorflow as tf
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
# Load the SBERT model
sbert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Uitility Functions

# %% [markdown]
# #### From Rich

# %%
def flatten_json(json_obj, parent_key='', separator='_'):
    """
    Flatten a nested JSON object.

    Parameters:
    json_obj (dict): The nested JSON object to flatten.
    parent_key (str): The parent key for nested keys (used for recursion).
    separator (str): The separator used to concatenate nested keys.

    Returns:
    dict: The flattened JSON object.
    """
    items = {}
    for key, value in json_obj.items():
        new_key = parent_key + separator + key if parent_key else key
        if isinstance(value, dict):
            items.update(flatten_json(value, new_key, separator=separator).items())
        else:
            items[new_key] = value
    return items

def flat_list(json_list, parent_key='', separator='_'):
  olist=list()
  for item in json_list:
    olist.append(flatten_json(item))
  return olist

def extended_describe(df):
  info_df = df.describe(include="all").T
  info_df['Data Type'] = df.dtypes
  info_df['Non-Null Count'] = df.notnull().sum()
  info_df['Null Count'] = df.isnull().sum()
  info_df['Null Percentage'] = ((info_df['Null Count'] / len(df)) * 100).round(4)
  return info_df

# %% [markdown]
# #### From Wesley

# %%
# Preprocess function
def preprocess_text(text):
    if isinstance(text,list):
        text=' '.join(text)
    text = text.lower()
    text = ' '.join([word for word in word_tokenize(text) if word.isalnum()])
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

def transform_text(data_text_column):
    data_text_column = data_text_column.apply(preprocess_text)

    # Generate embeddings
    embeddings = sbert_model.encode(data_text_column.tolist(), show_progress_bar=True)
    embeddings_np = np.array(embeddings)
    return embeddings_np

# Model training function
def lstm_classification_with_sentence_bert(data, target_column, lstm_units=128, dropout_rate=0.2, recurrent_dropout_rate=0.2, epochs=10):
    labels = data[target_column].values

    # Select features other than 'summary', 'title', and 'T1_2'
    X = data.drop([ target_column], axis=1)
    print("A")
    # Compute class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(labels), y=labels)
    class_weight_dict = dict(enumerate(class_weights))

    # Split data into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, labels, test_size=0.2, random_state=42)
    print('B')
    # Define the LSTM model architecture
    input_layer = Input(shape=(X_train.shape[1],), dtype='float32')
    reshaped_layer = Reshape((X_train.shape[1], 1))(input_layer)
    lstm_layer = LSTM(lstm_units, dropout=dropout_rate, recurrent_dropout=recurrent_dropout_rate)(reshaped_layer)
    output = Dense(1, activation='sigmoid')(lstm_layer)
    model = Model(inputs=input_layer, outputs=output)
    print('C')
    # Compile and train the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    print('D')
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=32, validation_data=(X_val, y_val), verbose=1, class_weight=class_weight_dict)
    print('E')
    # Save the model
    model.save('final_model_t1.h5')

    return model, history

# %% [markdown]
# ### Mount Google Drive

# %%
# Mount Google Drive (if the file is stored in Google Drive)
drive.mount('/content/drive')

DATA_FOLDER= '/content/drive/MyDrive/DSBA-6156-Congress-Data'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading the Data

# %%
bills = list()
sessions = pd.read_csv(f'{DATA_FOLDER}/political_landscape.csv')
display(sessions)
session_map=dict()
for index, session in sessions.iterrows():
    # Create a dictionary for the current row
    row_dict = dict()
    for column in sessions.columns:
        if column != 'Congress':  # Exclude 'Congress' column from inner dictionary
            row_dict[column] = session[column]
    # Add the inner dictionary to the result dictionary with 'Congress' as key
    session_map[str(session['Congress'])] = row_dict
# print(json.dumps(session_map,indent=2))
for i in range (97,117):
    bills.extend(json.load(open(f'{DATA_FOLDER}/{i}.json')))

for bill in bills:
    congress=str(bill["congress"])
    bill.update(session_map[congress])

bills_df = pd.DataFrame(bills)
display(len(bills_df))
# Out:
#     Congress  S-Dem  S-Rep  S-Oth  HR-Dem  HR-Rep  HR-Oth  EC-Dem  EC-Rep  \
# 0         97     46     53      1     242     192       1      49     489
# 1         98     46     54      0     269     166       0      49     489
# 2         99     47     53      0     253     182       0      13     525
# 3        100     55     45      0     258     177       0      13     525
# 4        101     55     45      0     260     175       0     111     426
# 5        102     56     44      0     267     167       1     111     426
# 6        103     57     43      0     258     176       1     370     168
# 7        104     48     52      0     204     230       1     370     168
# 8        105     45     55      0     207     226       2     379     159
# 9        106     45     55      0     211     223       1     379     159
# 10       107     50     50      0     212     221       2     266     271
# 11       108     48     51      1     205     229       1     266     271
# 12       109     44     55      1     202     231       2     251     286
# 13       110     49     49      2     233     198       4     251     286
# 14       111     57     41      2     256     178       1     365     173
# 15       112     51     47      2     193     242       0     365     173
# 16       113     54     45      1     201     234       0     332     206
# 17       114     44     54      2     188     246       1     332     206
# 18       115     46     52      2     194     241       0     304     227
# 19       116     52     46      2     235     166       1     304     227
#
#     EC-Other   Pop-Dem   Pop-Rep  Pop-Other Pres  MidTerm
# 0        NaN  35480115  43903230    5719850    R        0
# 1        NaN  35480115  43903230    5719850    R        1
# 2        NaN  37577352  54455472          0    R        0
# 3        NaN  37577352  54455472          0    R        1
# 4        1.0  41809476  48886597          0    R        0
# 5        1.0  41809476  48886597          0    R        1
# 6        NaN  44909806  39104550   19743821    D        0
# 7        NaN  44909806  39104550   19743821    D        1
# 8        NaN  47401185  39197469    8085294    D        0
# 9        NaN  47401185  39197469    8085294    D        1
# 10       NaN  50999897  50456002          0    R        0
# 11       NaN  50999897  50456002          0    R        1
# 12       1.0  59028444  62040610          0    R        0
# 13       1.0  59028444  62040610          0    R        1
# 14       NaN  69498516  59948323          0    D        0
# 15       NaN  69498516  59948323          0    D        1
# 16       NaN  65915795  60933504          0    D        0
# 17       NaN  65915795  60933504          0    D        1
# 18       7.0  65853514  62984828     111609    R        0
# 19       7.0  65853514  62984828     111609    R        1
# 191464

# %%
T1_2_df = bills_df[bills_df["T1_2"] != "EXCLUDE"]
display(len(T1_2_df))
T2_3_df = bills_df[bills_df["T2_3"] != "EXCLUDE"]
display(len(T2_3_df))
#display(extended_describe(T2_3_df))
T1_2_df.to_csv(f'{DATA_FOLDER}/T1_2.csv')
T2_3_df.to_csv(f'{DATA_FOLDER}/T2_3.csv')
# Out:
# 191052
# 25957

# %%
## List of policy areas
# Show the unique Values
if False:
  display_markdown("## Unique Values of Bill Fields",raw=True)
  for col in ["policy_area"]:
    display_markdown(f'### {col}',raw=True)
    vals = T2_3_df[col].unique()
    for val in vals:
      display_markdown(f'* {val}',raw=True)

display(pd.DataFrame(T2_3_df['policy_area'].value_counts()).sort_values(by='count', ascending=False))
# Out:
#                                       count
# policy_area
# Public lands and natural resources     2456
# Government operations and politics     2271
# Armed forces and national security     1618
# Health                                 1117
# International affairs                  1031
# ...                                     ...
# Continental shelf                         1
# Oil pollution                             1
# Supplemental security income program      1
# Special prosecutors                       1
# International organization                1
#
# [656 rows x 1 columns]

# %% [markdown]
# ## No Text Models

# %% [markdown]
# ### Preprocess

# %%
T2_3_trim_df = T2_3_df.drop(['congress','number','intro_date','actions','level','stages','T0_1','T1_2','T3_4'],axis=1)
T2_3_trim_df['pres_is_dem'] = T2_3_trim_df.apply(lambda row: 1 if row["Pres"]=="D" else 0,axis=1)
T2_3_trim_df['is_senate'] = T2_3_trim_df.apply(lambda row: 1 if row["bill_type"]=="s" else 0,axis=1)
T2_3_trim_df['sponsor_is_dem'] = T2_3_trim_df.apply(lambda row:  1 if row["sponsor"]["party"]=="Democratic" else 0,axis=1)
T2_3_trim_df['sponsor_is_rep'] = T2_3_trim_df.apply(lambda row:  1 if row["sponsor"]["party"]=="Republican" else 0,axis=1)
T2_3_trim_df['cosponsor_dem'] = T2_3_trim_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if cosponsor["party"] == "Republican"), axis=1)
T2_3_trim_df['cosponsor_rep'] = T2_3_trim_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if cosponsor["party"] == "Democratic"), axis=1)
T2_3_trim_df['cosponsor_oth'] = T2_3_trim_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if not cosponsor["party"] in ["Republican","Democratic"]), axis=1)
T2_3_trim_df=T2_3_trim_df.drop(['sponsor','cosponsors',"Pres","bill_type"],axis=1)
display(extended_describe(T2_3_trim_df))
T2_3_trim_df.to_csv(f'{DATA_FOLDER}/T2_3_trim.csv',index=False)
# Out:
#                   count unique  \
# title             25957  23125
# summary           25780  24738
# T2_3              25957      2
# policy_area       25939    656
# subjects          25957  21693
# S-Dem           25957.0    NaN
# S-Rep           25957.0    NaN
# S-Oth           25957.0    NaN
# HR-Dem          25957.0    NaN
# HR-Rep          25957.0    NaN
# HR-Oth          25957.0    NaN
# EC-Dem          25957.0    NaN
# EC-Rep          25957.0    NaN
# EC-Other         8971.0    NaN
# Pop-Dem         25957.0    NaN
# Pop-Rep         25957.0    NaN
# Pop-Other       25957.0    NaN
# MidTerm         25957.0    NaN
# pres_is_dem     25957.0    NaN
# is_senate       25957.0    NaN
# sponsor_is_dem  25957.0    NaN
# sponsor_is_rep  25957.0    NaN
# cosponsor_dem   25957.0    NaN
# cosponsor_rep   25957.0    NaN
# cosponsor_oth   25957.0    NaN
#
#                                                               top   freq  \
# title           To provide an extension of highway, highway sa...     11
# summary         Declares a named individual to have been lawfu...     80
# T2_3                                                        FALSE  17818
# policy_area                    Public lands and natural resources   2456
# subjects                       [Immigration, Private legislation]    338
# S-Dem                                                         NaN    NaN
# S-Rep                                                         NaN    NaN
# S-Oth                                                         NaN    NaN
# HR-Dem                                                        NaN    NaN
# HR-Rep                                                        NaN    NaN
# HR-Oth                                                        NaN    NaN
# EC-Dem                                                        NaN    NaN
# EC-Rep                                                        NaN    NaN
# EC-Other                                                      NaN    NaN
# Pop-Dem                                                       NaN    NaN
# Pop-Rep                                                       NaN    NaN
# Pop-Other                                                     NaN    NaN
# MidTerm                                                       NaN    NaN
# pres_is_dem                                                   NaN    NaN
# is_senate                                                     NaN    NaN
# sponsor_is_dem                                                NaN    NaN
# sponsor_is_rep                                                NaN    NaN
# cosponsor_dem                                                 NaN    NaN
# cosponsor_rep                                                 NaN    NaN
# cosponsor_oth                                                 NaN    NaN
#
#                            mean              std         min         25%  \
# title                       NaN              NaN         NaN         NaN
# summary                     NaN              NaN         NaN         NaN
# T2_3                        NaN              NaN         NaN         NaN
# policy_area                 NaN              NaN         NaN         NaN
# subjects                    NaN              NaN         NaN         NaN
# S-Dem                 49.643487         4.403311        44.0        46.0
# S-Rep                 49.495088         4.384222        41.0        45.0
# S-Oth                  0.861425         0.889281         0.0         0.0
# HR-Dem               227.471164        27.683476       188.0       202.0
# HR-Rep               204.643025        29.141945       166.0       176.0
# HR-Oth                 0.963555         1.037729         0.0         0.0
# EC-Dem               241.600185       127.948217        13.0       111.0
# EC-Rep               295.204492       128.316183       159.0       173.0
# EC-Other               3.194404         2.889973         1.0         1.0
# Pop-Dem         52295150.197943  11867376.639209  35480115.0  41809476.0
# Pop-Rep         52819527.087761   8794553.108666  39104550.0  43903230.0
# Pop-Other        2973103.082367   5710218.854736         0.0         0.0
# MidTerm                0.518781         0.499657         0.0         0.0
# pres_is_dem            0.367993         0.482269         0.0         0.0
# is_senate              0.424818         0.494325         0.0         0.0
# sponsor_is_dem         0.496668         0.499999         0.0         0.0
# sponsor_is_rep         0.496513         0.499997         0.0         0.0
# cosponsor_dem          6.740032        18.931052         0.0         0.0
# cosponsor_rep          8.791386        23.503756         0.0         0.0
# cosponsor_oth          0.098586         0.346966         0.0         0.0
#
#                        50%         75%         max Data Type  Non-Null Count  \
# title                  NaN         NaN         NaN    object           25957
# summary                NaN         NaN         NaN    object           25780
# T2_3                   NaN         NaN         NaN    object           25957
# policy_area            NaN         NaN         NaN    object           25939
# subjects               NaN         NaN         NaN    object           25957
# S-Dem                 48.0        54.0        57.0     int64           25957
# S-Rep                 51.0        54.0        55.0     int64           25957
# S-Oth                  1.0         2.0         2.0     int64           25957
# HR-Dem               233.0       258.0       269.0     int64           25957
# HR-Rep               198.0       231.0       246.0     int64           25957
# HR-Oth                 1.0         1.0         4.0     int64           25957
# EC-Dem               266.0       365.0       379.0     int64           25957
# EC-Rep               271.0       426.0       525.0     int64           25957
# EC-Other               1.0         7.0         7.0   float64            8971
# Pop-Dem         50999897.0  65853514.0  69498516.0     int64           25957
# Pop-Rep         54455472.0  60933504.0  62984828.0     int64           25957
# Pop-Other              0.0   5719850.0  19743821.0     int64           25957
# MidTerm                1.0         1.0         1.0     int64           25957
# pres_is_dem            0.0         1.0         1.0     int64           25957
# is_senate              0.0         1.0         1.0     int64           25957
# sponsor_is_dem         0.0         1.0         1.0     int64           25957
# sponsor_is_rep         0.0         1.0         1.0     int64           25957
# cosponsor_dem          1.0         5.0       240.0     int64           25957
# cosponsor_rep          1.0         6.0       241.0     int64           25957
# cosponsor_oth          0.0         0.0         3.0     int64           25957
#
#                 Null Count  Null Percentage
# title                    0           0.0000
# summary                177           0.6819
# T2_3                     0           0.0000
# policy_area             18           0.0693
# subjects                 0           0.0000
# S-Dem                    0           0.0000
# S-Rep                    0           0.0000
# S-Oth                    0           0.0000
# HR-Dem                   0           0.0000
# HR-Rep                   0           0.0000
# HR-Oth                   0           0.0000
# EC-Dem                   0           0.0000
# EC-Rep                   0           0.0000
# EC-Other             16986          65.4390
# Pop-Dem                  0           0.0000
# Pop-Rep                  0           0.0000
# Pop-Other                0           0.0000
# MidTerm                  0           0.0000
# pres_is_dem              0           0.0000
# is_senate                0           0.0000
# sponsor_is_dem           0           0.0000
# sponsor_is_rep           0           0.0000
# cosponsor_dem            0           0.0000
# cosponsor_rep            0           0.0000
# cosponsor_oth            0           0.0000

# %% [markdown]
# ## Policy Area `Energy`

# %%
energy_df = T2_3_df[T2_3_df["policy_area"] == "Energy"].drop(['congress','number','intro_date','actions','level','stages','T0_1','T1_2','T3_4','policy_area'],axis=1)
energy_df['pres_is_dem'] = energy_df.apply(lambda row: row["Pres"]=="D",axis=1)
energy_df['senate'] = energy_df.apply(lambda row: row["bill_type"]=="s",axis=1)
energy_df['sponsor_is_dem'] = energy_df.apply(lambda row: row["sponsor"]["party"]=="Democratic",axis=1)
energy_df['sponsor_is_rep'] = energy_df.apply(lambda row: row["sponsor"]["party"]=="Republican",axis=1)
energy_df['cosponsor_dem'] = energy_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if cosponsor["party"] == "Republican"), axis=1)
energy_df['cosponsor_rep'] = energy_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if cosponsor["party"] == "Democratic"), axis=1)
energy_df['cosponsor_oth'] = energy_df.apply(lambda row: sum(1 for cosponsor in row["cosponsors"] if not cosponsor["party"] in ["Republican","Democratic"]), axis=1)
energy_df=energy_df.drop(['sponsor','cosponsors',"Pres","bill_type"],axis=1)
display(extended_describe(energy_df))
#energy_df["title_x"] = transform_text(energy_df["title"])
#energy_df['title_y'] = energy_df['title'].apply(preprocess_text)
# Load the SBERT model
sbert_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Generate embeddings
#embeddings = sbert_model.encode(energy_df['title'].tolist(), show_progress_bar=True)
#embeddings_np = np.array(embeddings)
#energy_df['title']= embeddings_np]
energy_df=energy_df.drop(["title","subjects","summary"],axis=1)
display(extended_describe(energy_df))
lstm_classification_with_sentence_bert(energy_df,'T2_3')
# Out:
#                 count unique  \
# title             630    544
# summary           612    592
# T2_3              630      2
# subjects          630    521
# S-Dem           630.0    NaN
# S-Rep           630.0    NaN
# S-Oth           630.0    NaN
# HR-Dem          630.0    NaN
# HR-Rep          630.0    NaN
# HR-Oth          630.0    NaN
# EC-Dem          630.0    NaN
# EC-Rep          630.0    NaN
# EC-Other        257.0    NaN
# Pop-Dem         630.0    NaN
# Pop-Rep         630.0    NaN
# Pop-Other       630.0    NaN
# MidTerm         630.0    NaN
# pres_is_dem       630      2
# senate            630      2
# sponsor_is_dem    630      2
# sponsor_is_rep    630      2
# cosponsor_dem   630.0    NaN
# cosponsor_rep   630.0    NaN
# cosponsor_oth   630.0    NaN
#
#                                                               top freq  \
# title           To extend the deadline for commencement of con...    9
# summary         Amends the Federal Power Act to remove hydroel...    3
# T2_3                                                        FALSE  512
# subjects        [Administrative law and regulatory procedures,...    5
# S-Dem                                                         NaN  NaN
# S-Rep                                                         NaN  NaN
# S-Oth                                                         NaN  NaN
# HR-Dem                                                        NaN  NaN
# HR-Rep                                                        NaN  NaN
# HR-Oth                                                        NaN  NaN
# EC-Dem                                                        NaN  NaN
# EC-Rep                                                        NaN  NaN
# EC-Other                                                      NaN  NaN
# Pop-Dem                                                       NaN  NaN
# Pop-Rep                                                       NaN  NaN
# Pop-Other                                                     NaN  NaN
# MidTerm                                                       NaN  NaN
# pres_is_dem                                                 False  342
# senate                                                      False  326
# sponsor_is_dem                                              False  367
# sponsor_is_rep                                               True  358
# cosponsor_dem                                                 NaN  NaN
# cosponsor_rep                                                 NaN  NaN
# cosponsor_oth                                                 NaN  NaN
#
#                            mean              std         min         25%  \
# title                       NaN              NaN         NaN         NaN
# summary                     NaN              NaN         NaN         NaN
# T2_3                        NaN              NaN         NaN         NaN
# subjects                    NaN              NaN         NaN         NaN
# S-Dem                 49.619048         4.184644        44.0        46.0
# S-Rep                 49.242857         4.274344        41.0        46.0
# S-Oth                  1.138095         0.915322         0.0         0.0
# HR-Dem               218.560317        25.144707       188.0       194.0
# HR-Rep               211.542857        29.758657       166.0       178.0
# HR-Oth                 0.915873          0.98683         0.0         0.0
# EC-Dem               288.396825       101.350552        13.0       266.0
# EC-Rep               247.687302       101.493877       159.0       173.0
# EC-Other               4.548638         2.955161         1.0         1.0
# Pop-Dem         57324023.425397  10894694.064869  35480115.0  47401185.0
# Pop-Rep         55298329.704762   9011413.574336  39104550.0  48886597.0
# Pop-Other        2798922.711111    6164741.36729         0.0         0.0
# MidTerm                0.530159         0.499486         0.0         0.0
# pres_is_dem                 NaN              NaN         NaN         NaN
# senate                      NaN              NaN         NaN         NaN
# sponsor_is_dem              NaN              NaN         NaN         NaN
# sponsor_is_rep              NaN              NaN         NaN         NaN
# cosponsor_dem          5.144444        14.834104         0.0         0.0
# cosponsor_rep          5.163492        14.726989         0.0         0.0
# cosponsor_oth          0.073016         0.300083         0.0         0.0
#
#                        50%         75%         max Data Type  Non-Null Count  \
# title                  NaN         NaN         NaN    object             630
# summary                NaN         NaN         NaN    object             612
# T2_3                   NaN         NaN         NaN    object             630
# subjects               NaN         NaN         NaN    object             630
# S-Dem                 49.0        52.0        57.0     int64             630
# S-Rep                 50.0        52.0        55.0     int64             630
# S-Oth                  1.0         2.0         2.0     int64             630
# HR-Dem               207.0       235.0       267.0     int64             630
# HR-Rep               226.0       241.0       246.0     int64             630
# HR-Oth                 1.0         1.0         4.0     int64             630
# EC-Dem               304.0       365.0       379.0     int64             630
# EC-Rep               227.0       271.0       525.0     int64             630
# EC-Other               7.0         7.0         7.0   float64             257
# Pop-Dem         65853514.0  65915795.0  69498516.0     int64             630
# Pop-Rep         59948323.0  62040610.0  62984828.0     int64             630
# Pop-Other              0.0    111609.0  19743821.0     int64             630
# MidTerm                1.0         1.0         1.0     int64             630
# pres_is_dem            NaN         NaN         NaN      bool             630
# senate                 NaN         NaN         NaN      bool             630
# sponsor_is_dem         NaN         NaN         NaN      bool             630
# sponsor_is_rep         NaN         NaN         NaN      bool             630
# cosponsor_dem          1.0         3.0       140.0     int64             630
# cosponsor_rep          1.0         3.0       197.0     int64             630
# cosponsor_oth          0.0         0.0         2.0     int64             630
#
#                 Null Count  Null Percentage
# title                    0           0.0000
# summary                 18           2.8571
# T2_3                     0           0.0000
# subjects                 0           0.0000
# S-Dem                    0           0.0000
# S-Rep                    0           0.0000
# S-Oth                    0           0.0000
# HR-Dem                   0           0.0000
# HR-Rep                   0           0.0000
# HR-Oth                   0           0.0000
# EC-Dem                   0           0.0000
# EC-Rep                   0           0.0000
# EC-Other               373          59.2063
# Pop-Dem                  0           0.0000
# Pop-Rep                  0           0.0000
# Pop-Other                0           0.0000
# MidTerm                  0           0.0000
# pres_is_dem              0           0.0000
# senate                   0           0.0000
# sponsor_is_dem           0           0.0000
# sponsor_is_rep           0           0.0000
# cosponsor_dem            0           0.0000
# cosponsor_rep            0           0.0000
# cosponsor_oth            0           0.0000
#                 count unique    top freq             mean              std  \
# T2_3              630      2  FALSE  512              NaN              NaN
# S-Dem           630.0    NaN    NaN  NaN        49.619048         4.184644
# S-Rep           630.0    NaN    NaN  NaN        49.242857         4.274344
# S-Oth           630.0    NaN    NaN  NaN         1.138095         0.915322
# HR-Dem          630.0    NaN    NaN  NaN       218.560317        25.144707
# HR-Rep          630.0    NaN    NaN  NaN       211.542857        29.758657
# HR-Oth          630.0    NaN    NaN  NaN         0.915873          0.98683
# EC-Dem          630.0    NaN    NaN  NaN       288.396825       101.350552
# EC-Rep          630.0    NaN    NaN  NaN       247.687302       101.493877
# EC-Other        257.0    NaN    NaN  NaN         4.548638         2.955161
# Pop-Dem         630.0    NaN    NaN  NaN  57324023.425397  10894694.064869
# Pop-Rep         630.0    NaN    NaN  NaN  55298329.704762   9011413.574336
# Pop-Other       630.0    NaN    NaN  NaN   2798922.711111    6164741.36729
# MidTerm         630.0    NaN    NaN  NaN         0.530159         0.499486
# pres_is_dem       630      2  False  342              NaN              NaN
# senate            630      2  False  326              NaN              NaN
# sponsor_is_dem    630      2  False  367              NaN              NaN
# sponsor_is_rep    630      2   True  358              NaN              NaN
# cosponsor_dem   630.0    NaN    NaN  NaN         5.144444        14.834104
# cosponsor_rep   630.0    NaN    NaN  NaN         5.163492        14.726989
# cosponsor_oth   630.0    NaN    NaN  NaN         0.073016         0.300083
#
#                        min         25%         50%         75%         max  \
# T2_3                   NaN         NaN         NaN         NaN         NaN
# S-Dem                 44.0        46.0        49.0        52.0        57.0
# S-Rep                 41.0        46.0        50.0        52.0        55.0
# S-Oth                  0.0         0.0         1.0         2.0         2.0
# HR-Dem               188.0       194.0       207.0       235.0       267.0
# HR-Rep               166.0       178.0       226.0       241.0       246.0
# HR-Oth                 0.0         0.0         1.0         1.0         4.0
# EC-Dem                13.0       266.0       304.0       365.0       379.0
# EC-Rep               159.0       173.0       227.0       271.0       525.0
# EC-Other               1.0         1.0         7.0         7.0         7.0
# Pop-Dem         35480115.0  47401185.0  65853514.0  65915795.0  69498516.0
# Pop-Rep         39104550.0  48886597.0  59948323.0  62040610.0  62984828.0
# Pop-Other              0.0         0.0         0.0    111609.0  19743821.0
# MidTerm                0.0         0.0         1.0         1.0         1.0
# pres_is_dem            NaN         NaN         NaN         NaN         NaN
# senate                 NaN         NaN         NaN         NaN         NaN
# sponsor_is_dem         NaN         NaN         NaN         NaN         NaN
# sponsor_is_rep         NaN         NaN         NaN         NaN         NaN
# cosponsor_dem          0.0         0.0         1.0         3.0       140.0
# cosponsor_rep          0.0         0.0         1.0         3.0       197.0
# cosponsor_oth          0.0         0.0         0.0         0.0         2.0
#
#                Data Type  Non-Null Count  Null Count  Null Percentage
# T2_3              object             630           0           0.0000
# S-Dem              int64             630           0           0.0000
# S-Rep              int64             630           0           0.0000
# S-Oth              int64             630           0           0.0000
# HR-Dem             int64             630           0           0.0000
# HR-Rep             int64             630           0           0.0000
# HR-Oth             int64             630           0           0.0000
# EC-Dem             int64             630           0           0.0000
# EC-Rep             int64             630           0           0.0000
# EC-Other         float64             257         373          59.2063
# Pop-Dem            int64             630           0           0.0000
# Pop-Rep            int64             630           0           0.0000
# Pop-Other          int64             630           0           0.0000
# MidTerm            int64             630           0           0.0000
# pres_is_dem         bool             630           0           0.0000
# senate              bool             630           0           0.0000
# sponsor_is_dem      bool             630           0           0.0000
# sponsor_is_rep      bool             630           0           0.0000
# cosponsor_dem      int64             630           0           0.0000
# cosponsor_rep      int64             630           0           0.0000
# cosponsor_oth      int64             630           0           0.0000
# A
# B
# C
# D
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5dbdd51f63c9> in <cell line: 21>()
#      19 energy_df=energy_df.drop(["title","subjects","summary"],axis=1)
#      20 display(extended_describe(energy_df))
# ---> 21 lstm_classification_with_sentence_bert(energy_df,'T2_3')
#
# <ipython-input-8-61a07091970a> in lstm_classification_with_sentence_bert(data, target_column, lstm_units, dropout_rate, recurrent_dropout_rate, epochs)
#      41     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      42     print('D')
# ---> 43     history = model.fit(X_train, y_train, epochs=epochs, batch_size=32, validation_data=(X_val, y_val), verbose=1, class_weight=class_weight_dict)
#      44     print('E')
#      45     # Save the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).

# %% [markdown]
# ## GovInfo.gov
#
# These API calls connect to https://api.govinfo.gov/docs/

# %% [markdown]
# ### Get the list of colletions
#
# Here we are just testing out the access

# %%
r=requests.get(
    "https://api.govinfo.gov/collections",
    headers={ "X-Api-Key": "k414JzxlJKuFweSHI5IC7DPqeOgPj6fyA7X5D4Bz"}
)
#print(json.dumps(r.json(),indent=2))
df = pd.DataFrame(r.json()["collections"])
display(df)
# Out:
#    collectionCode                                     collectionName  \
# 0           BILLS                                Congressional Bills
# 1      BILLSTATUS                          Congressional Bill Status
# 2          BUDGET                               United States Budget
# 3            CCAL                            Congressional Calendars
# 4            CDIR                            Congressional Directory
# 5            CDOC                            Congressional Documents
# 6             CFR                        Code of Federal Regulations
# 7            CHRG                             Congressional Hearings
# 8             CMR                   Congressionally Mandated Reports
# 9           COMPS                              Statutes Compilations
# 10            CPD              Compilation of Presidential Documents
# 11           CPRT                     Congressional Committee Prints
# 12           CREC                               Congressional Record
# 13          CRECB               Congressional Record (Bound Edition)
# 14            CRI                         Congressional Record Index
# 15           CRPT                              Congressional Reports
# 16           CZIC                    Coastal Zone Information Center
# 17           ECFR             Electronic Code of Federal Regulations
# 18          ECONI                                Economic Indicators
# 19           ERIC                        Education Reports from ERIC
# 20            ERP                   Economic Report of the President
# 21             FR                                   Federal Register
# 22     GAOREPORTS  Government Accountability Office Reports and C...
# 23         GOVMAN                    United States Government Manual
# 24         GOVPUB                                    Bulk Submission
# 25            GPO                 Additional Government Publications
# 26       HJOURNAL            Journal of the House of Representatives
# 27           HMAN                             House Rules and Manual
# 28            HOB                                   History of Bills
# 29            LSA                      List of CFR Sections Affected
# 30            PAI                              Privacy Act Issuances
# 31           PLAW                            Public and Private Laws
# 32            PPP  Public Papers of the Presidents of the United ...
# 33      SERIALSET                           Congressional Serial Set
# 34       SJOURNAL                              Journal of the Senate
# 35           SMAN                                      Senate Manual
# 36        STATUTE                                  Statutes at Large
# 37         USCODE                                 United States Code
# 38       USCOURTS                      United States Courts Opinions
#
#     packageCount  granuleCount
# 0         261027           NaN
# 1         148382           NaN
# 2            348        6956.0
# 3           5555       88897.0
# 4            237       15024.0
# 5          25478        9653.0
# 6           6131     7209523.0
# 7          41329         285.0
# 8            292           NaN
# 9           2452           NaN
# 10         15865       23012.0
# 11          2589        1670.0
# 12          5509      790559.0
# 13          2400      464102.0
# 14            42      605412.0
# 15         47404         560.0
# 16          4883           NaN
# 17            49           NaN
# 18           347       16651.0
# 19           563           NaN
# 20            29        2886.0
# 21         22190      944367.0
# 22         16569           NaN
# 23            27        4874.0
# 24        100600         321.0
# 25          4228       79919.0
# 26           144       33948.0
# 27            15        2109.0
# 28            42      298591.0
# 29           330       17099.0
# 30          1561           NaN
# 31          5662           NaN
# 32           180       24847.0
# 33         57142           NaN
# 34           149           NaN
# 35             8        1310.0
# 36            68       37618.0
# 37          1446     1877490.0
# 38       1848843     3998116.0

# %% [markdown]
# ### List of Bills

# %%
r=requests.get(
    "https://api.govinfo.gov/collections/BILLS/1979-01-28T20:18:10Z",
    headers={ "X-Api-Key": "k414JzxlJKuFweSHI5IC7DPqeOgPj6fyA7X5D4Bz"},
    params={
        "pageSize": 1000,
        "offsetMark": "*"
    }
)
print(json.dumps(r.json()["packages"][0],indent=2))
df = pd.DataFrame(r.json()["packages"])
display(df)
# Out:
# {
#   "packageId": "BILLS-118hr7671ih",
#   "lastModified": "2024-03-28T04:16:19Z",
#   "packageLink": "https://api.govinfo.gov/packages/BILLS-118hr7671ih/summary",
#   "docClass": "hr",
#   "title": "Disaster Management Costs Modernization Act",
#   "congress": "118",
#   "dateIssued": "2024-03-13"
# }
#              packageId          lastModified  \
# 0    BILLS-118hr7671ih  2024-03-28T04:16:19Z
# 1    BILLS-118hr7672ih  2024-03-28T04:16:04Z
# 2    BILLS-118hr7661ih  2024-03-28T02:18:28Z
# 3    BILLS-118hr7670ih  2024-03-28T02:18:23Z
# 4    BILLS-118hr7665ih  2024-03-28T02:18:23Z
# ..                 ...                   ...
# 995  BILLS-118hr7226ih  2024-02-16T07:17:43Z
# 996  BILLS-118hr5375eh  2024-02-16T06:10:27Z
# 997  BILLS-118hr7176eh  2024-02-16T06:10:17Z
# 998   BILLS-118hr533eh  2024-02-16T06:10:17Z
# 999  BILLS-118hr2766eh  2024-02-16T06:10:11Z
#
#                                            packageLink docClass  \
# 0    https://api.govinfo.gov/packages/BILLS-118hr76...       hr
# 1    https://api.govinfo.gov/packages/BILLS-118hr76...       hr
# 2    https://api.govinfo.gov/packages/BILLS-118hr76...       hr
# 3    https://api.govinfo.gov/packages/BILLS-118hr76...       hr
# 4    https://api.govinfo.gov/packages/BILLS-118hr76...       hr
# ..                                                 ...      ...
# 995  https://api.govinfo.gov/packages/BILLS-118hr72...       hr
# 996  https://api.govinfo.gov/packages/BILLS-118hr53...       hr
# 997  https://api.govinfo.gov/packages/BILLS-118hr71...       hr
# 998  https://api.govinfo.gov/packages/BILLS-118hr53...       hr
# 999  https://api.govinfo.gov/packages/BILLS-118hr27...       hr
#
#                                                  title congress  dateIssued
# 0          Disaster Management Costs Modernization Act      118  2024-03-13
# 1    To amend title 40, United States Code, to perm...      118  2024-03-13
# 2     Taiwan and American Space Assistance Act of 2024      118  2024-03-13
# 3    Minks In Narrowly Kept Spaces are Superspreade...      118  2024-03-13
# 4               ACO Assignment Improvement Act of 2024      118  2024-03-13
# ..                                                 ...      ...         ...
# 995  Advancing Lifesaving Efforts with Rapid Test s...      118  2024-02-05
# 996                         Strengthening the Quad Act      118  2024-02-15
# 997   Unlocking our Domestic LNG Potential Act of 2024      118  2024-02-15
# 998  Promoting a Resolution to the Tibet-China Disp...      118  2024-02-15
# 999                          Uyghur Policy Act of 2023      118  2024-02-15
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Bill Status

# %%
r=requests.get(
    "https://api.govinfo.gov/collections/BILLSTATUS/1979-01-28T20:18:10Z",
    headers={ "X-Api-Key": "k414JzxlJKuFweSHI5IC7DPqeOgPj6fyA7X5D4Bz"},
    params={
        "pageSize": 1000,
        "offsetMark": "*"
    }
)
print(json.dumps(r.json()["packages"][0],indent=2))
df = pd.DataFrame(r.json()["packages"])
display(df)
# Out:
# {
#   "packageId": "BILLSTATUS-118hr7659",
#   "lastModified": "2024-03-28T01:39:00Z",
#   "packageLink": "https://api.govinfo.gov/packages/BILLSTATUS-118hr7659/summary",
#   "docClass": "hr",
#   "title": null,
#   "congress": "118",
#   "dateIssued": "2024-03-28"
# }
#                    packageId          lastModified  \
# 0       BILLSTATUS-118hr7659  2024-03-28T01:39:00Z
# 1       BILLSTATUS-118hr7792  2024-03-28T01:38:55Z
# 2       BILLSTATUS-118hr4541  2024-03-28T01:38:54Z
# 3     BILLSTATUS-118hres1108  2024-03-28T01:38:50Z
# 4       BILLSTATUS-118hr7155  2024-03-28T01:38:40Z
# ..                       ...                   ...
# 995      BILLSTATUS-118s3631  2024-03-22T17:33:35Z
# 996     BILLSTATUS-118hr7660  2024-03-22T17:32:50Z
# 997     BILLSTATUS-118hr7662  2024-03-22T17:29:29Z
# 998  BILLSTATUS-118hconres93  2024-03-22T17:26:59Z
# 999      BILLSTATUS-118s2675  2024-03-22T17:26:58Z
#
#                                            packageLink docClass title  \
# 0    https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# 1    https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# 2    https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# 3    https://api.govinfo.gov/packages/BILLSTATUS-11...     hres  None
# 4    https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# ..                                                 ...      ...   ...
# 995  https://api.govinfo.gov/packages/BILLSTATUS-11...        s  None
# 996  https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# 997  https://api.govinfo.gov/packages/BILLSTATUS-11...       hr  None
# 998  https://api.govinfo.gov/packages/BILLSTATUS-11...  hconres  None
# 999  https://api.govinfo.gov/packages/BILLSTATUS-11...        s  None
#
#     congress  dateIssued
# 0        118  2024-03-28
# 1        118  2024-03-28
# 2        118  2024-03-28
# 3        118  2024-03-28
# 4        118  2024-03-28
# ..       ...         ...
# 995      118  2024-03-22
# 996      118  2024-03-22
# 997      118  2024-03-22
# 998      118  2024-03-22
# 999      118  2024-03-22
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Congress.gov
#
# These API calls connect to https://api.congress.gov/

# %% [markdown]
# ### List of Senate Bills for the 118th Congress

# %%
r=requests.get(
    "https://api.congress.gov/v3/bill/118/s",
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={
        "limit": 250,
        "format": "json",
        "offset": 250,
        "sort": "updateDate+desc"
    }
)
print(json.dumps(r.json()["pagination"],indent=2))
df = pd.DataFrame(flat_list(r.json()["bills"]))
print(json.dumps(r.json()["bills"][0],indent=2))
print(json.dumps(requests.get(
    f'https://api.congress.gov/v3/bill/118/s/{r.json()["bills"][0]["number"]}',
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={"format": "json"}
).json(),indent=2))
print(json.dumps(r.json()["bills"][-1],indent=2))
print(json.dumps(requests.get(
    f'https://api.congress.gov/v3/bill/118/s/{r.json()["bills"][-1]["number"]}',
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={"format": "json"}
).json(),indent=2))
display(df)
# Out:
# {
#   "count": 4071,
#   "next": "https://api.congress.gov/v3/bill/118/s?sort=updateDate+desc&offset=500&limit=250&format=json",
#   "prev": "https://api.congress.gov/v3/bill/118/s?sort=updateDate+desc&offset=0&limit=250&format=json"
# }
# {
#   "congress": 118,
#   "latestAction": {
#     "actionDate": "2024-03-05",
#     "text": "Read twice and referred to the Committee on Finance."
#   },
#   "number": "3866",
#   "originChamber": "Senate",
#   "originChamberCode": "S",
#   "title": "Declaring Our Energy Independence from China Act of 2024",
#   "type": "S",
#   "updateDate": "2024-03-21",
#   "updateDateIncludingText": "2024-03-21T08:08:29Z",
#   "url": "https://api.congress.gov/v3/bill/118/s/3866?format=json"
# }
# {
#   "bill": {
#     "actions": {
#       "count": 2,
#       "url": "https://api.congress.gov/v3/bill/118/s/3866/actions?format=json"
#     },
#     "committees": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3866/committees?format=json"
#     },
#     "congress": 118,
#     "introducedDate": "2024-03-05",
#     "latestAction": {
#       "actionDate": "2024-03-05",
#       "text": "Read twice and referred to the Committee on Finance."
#     },
#     "number": "3866",
#     "originChamber": "Senate",
#     "originChamberCode": "S",
#     "policyArea": {
#       "name": "Foreign Trade and International Finance"
#     },
#     "sponsors": [
#       {
#         "bioguideId": "H001089",
#         "firstName": "Josh",
#         "fullName": "Sen. Hawley, Josh [R-MO]",
#         "isByRequest": "N",
#         "lastName": "Hawley",
#         "party": "R",
#         "state": "MO",
#         "url": "https://api.congress.gov/v3/member/H001089?format=json"
#       }
#     ],
#     "subjects": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3866/subjects?format=json"
#     },
#     "textVersions": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3866/text?format=json"
#     },
#     "title": "Declaring Our Energy Independence from China Act of 2024",
#     "titles": {
#       "count": 4,
#       "url": "https://api.congress.gov/v3/bill/118/s/3866/titles?format=json"
#     },
#     "type": "S",
#     "updateDate": "2024-03-21T08:08:29Z",
#     "updateDateIncludingText": "2024-03-21T08:08:29Z"
#   },
#   "request": {
#     "billNumber": "3866",
#     "billType": "s",
#     "congress": "118",
#     "contentType": "application/json",
#     "format": "json"
#   }
# }
# {
#   "congress": 118,
#   "latestAction": {
#     "actionDate": "2024-01-24",
#     "text": "Read twice and referred to the Committee on Finance."
#   },
#   "number": "3651",
#   "originChamber": "Senate",
#   "originChamberCode": "S",
#   "title": "Telemental Health Care Access Act of 2024",
#   "type": "S",
#   "updateDate": "2024-03-21",
#   "updateDateIncludingText": "2024-03-21T15:09:39Z",
#   "url": "https://api.congress.gov/v3/bill/118/s/3651?format=json"
# }
# {
#   "bill": {
#     "actions": {
#       "count": 2,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/actions?format=json"
#     },
#     "committees": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/committees?format=json"
#     },
#     "congress": 118,
#     "cosponsors": {
#       "count": 4,
#       "countIncludingWithdrawnCosponsors": 4,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/cosponsors?format=json"
#     },
#     "introducedDate": "2024-01-24",
#     "latestAction": {
#       "actionDate": "2024-01-24",
#       "text": "Read twice and referred to the Committee on Finance."
#     },
#     "number": "3651",
#     "originChamber": "Senate",
#     "originChamberCode": "S",
#     "policyArea": {
#       "name": "Health"
#     },
#     "relatedBills": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/relatedbills?format=json"
#     },
#     "sponsors": [
#       {
#         "bioguideId": "C001075",
#         "firstName": "Bill",
#         "fullName": "Sen. Cassidy, Bill [R-LA]",
#         "isByRequest": "N",
#         "lastName": "Cassidy",
#         "party": "R",
#         "state": "LA",
#         "url": "https://api.congress.gov/v3/member/C001075?format=json"
#       }
#     ],
#     "subjects": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/subjects?format=json"
#     },
#     "summaries": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/summaries?format=json"
#     },
#     "textVersions": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/text?format=json"
#     },
#     "title": "Telemental Health Care Access Act of 2024",
#     "titles": {
#       "count": 4,
#       "url": "https://api.congress.gov/v3/bill/118/s/3651/titles?format=json"
#     },
#     "type": "S",
#     "updateDate": "2024-03-21T15:09:39Z",
#     "updateDateIncludingText": "2024-03-21T15:09:39Z"
#   },
#   "request": {
#     "billNumber": "3651",
#     "billType": "s",
#     "congress": "118",
#     "contentType": "application/json",
#     "format": "json"
#   }
# }
#      congress latestAction_actionDate  \
# 0         118              2024-03-05
# 1         118              2024-03-05
# 2         118              2024-03-05
# 3         118              2024-03-01
# 4         118              2024-03-01
# ..        ...                     ...
# 245       118              2024-01-24
# 246       118              2024-01-24
# 247       118              2024-01-24
# 248       118              2024-01-24
# 249       118              2024-01-24
#
#                                      latestAction_text number originChamber  \
# 0    Read twice and referred to the Committee on Fi...   3866        Senate
# 1    Read twice and referred to the Committee on He...   3864        Senate
# 2    Read twice and referred to the Committee on Fi...   3860        Senate
# 3                                    Held at the desk.   3859        Senate
# 4                                    Held at the desk.   3706        Senate
# ..                                                 ...    ...           ...
# 245  Read twice and referred to the Committee on En...   3655        Senate
# 246  Committee on Small Business and Entrepreneursh...   1108        Senate
# 247  Read twice and referred to the Committee on He...   3653        Senate
# 248  Read twice and referred to the Committee on Ba...   3652        Senate
# 249  Read twice and referred to the Committee on Fi...   3651        Senate
#
#     originChamberCode                                              title type  \
# 0                   S  Declaring Our Energy Independence from China A...    S
# 1                   S                               Stop CMV Act of 2024    S
# 2                   S              Nurse Overtime and Patient Safety Act    S
# 3                   S                     Justice for Murder Victims Act    S
# 4                   S                                Victims' VOICES Act    S
# ..                ...                                                ...  ...
# 245                 S              Strategically Lowering Gas Prices Act    S
# 246                 S                       Death Tax Repeal Act of 2023    S
# 247                 S              Resources To Prevent Youth Vaping Act    S
# 248                 S             Housing Temperature Safety Act of 2024    S
# 249                 S          Telemental Health Care Access Act of 2024    S
#
#      updateDate updateDateIncludingText  \
# 0    2024-03-21    2024-03-21T08:08:29Z
# 1    2024-03-27    2024-03-27T20:45:22Z
# 2    2024-03-27    2024-03-27T20:45:22Z
# 3    2024-03-27    2024-03-27T11:35:26Z
# 4    2024-03-21    2024-03-21T15:08:32Z
# ..          ...                     ...
# 245  2024-02-28    2024-02-28T20:17:47Z
# 246  2024-03-18    2024-03-18T15:08:22Z
# 247  2024-03-18    2024-03-18T15:08:43Z
# 248  2024-02-28    2024-02-28T20:17:49Z
# 249  2024-03-21    2024-03-21T15:09:39Z
#
#                                                    url latestAction_actionTime
# 0    https://api.congress.gov/v3/bill/118/s/3866?fo...                     NaN
# 1    https://api.congress.gov/v3/bill/118/s/3864?fo...                     NaN
# 2    https://api.congress.gov/v3/bill/118/s/3860?fo...                     NaN
# 3    https://api.congress.gov/v3/bill/118/s/3859?fo...                10:10:05
# 4    https://api.congress.gov/v3/bill/118/s/3706?fo...                10:09:57
# ..                                                 ...                     ...
# 245  https://api.congress.gov/v3/bill/118/s/3655?fo...                     NaN
# 246  https://api.congress.gov/v3/bill/118/s/1108?fo...                     NaN
# 247  https://api.congress.gov/v3/bill/118/s/3653?fo...                     NaN
# 248  https://api.congress.gov/v3/bill/118/s/3652?fo...                     NaN
# 249  https://api.congress.gov/v3/bill/118/s/3651?fo...                     NaN
#
# [250 rows x 12 columns]

# %% [markdown]
# ### List of House Bills for the 118th Congress

# %%
r=requests.get(
    "https://api.congress.gov/v3/bill/118/hr",
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={
        "limit": 250,
        "format": "json",
        "offset": 250,
        "sort": "updateDate+desc"
    }
)
print(json.dumps(r.json()["pagination"],indent=2))
df = pd.DataFrame(flat_list(r.json()["bills"]))
print(json.dumps(r.json()["bills"][0],indent=2))
print(json.dumps(requests.get(
    f'https://api.congress.gov/v3/bill/118/hr/{r.json()["bills"][0]["number"]}',
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={"format": "json"}
).json(),indent=2))
print(json.dumps(r.json()["bills"][-1],indent=2))
print(json.dumps(requests.get(
    f'https://api.congress.gov/v3/bill/118/hr/{r.json()["bills"][-1]["number"]}',
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={"format": "json"}
).json(),indent=2))
display(df)
# Out:
# {
#   "count": 7822,
#   "next": "https://api.congress.gov/v3/bill/118/hr?sort=updateDate+desc&offset=500&limit=250&format=json",
#   "prev": "https://api.congress.gov/v3/bill/118/hr?sort=updateDate+desc&offset=0&limit=250&format=json"
# }
# {
#   "congress": 118,
#   "latestAction": {
#     "actionDate": "2024-03-13",
#     "text": "Referred to the House Committee on Transportation and Infrastructure."
#   },
#   "number": "7660",
#   "originChamber": "House",
#   "originChamberCode": "H",
#   "title": "Backcountry Aviation Protection Act",
#   "type": "HR",
#   "updateDate": "2024-03-22",
#   "updateDateIncludingText": "2024-03-22T14:15:50Z",
#   "url": "https://api.congress.gov/v3/bill/118/hr/7660?format=json"
# }
# {
#   "bill": {
#     "actions": {
#       "count": 3,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/actions?format=json"
#     },
#     "committees": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/committees?format=json"
#     },
#     "congress": 118,
#     "constitutionalAuthorityStatementText": "<pre>\n[Congressional Record Volume 170, Number 45 (Wednesday, March 13, 2024)]\n[House]\nFrom the Congressional Record Online through the Government Publishing Office [<a href=\"https://www.gpo.gov\">www.gpo.gov</a>]\nBy Ms. HAGEMAN:\nH.R. 7660.\nCongress has the power to enact this legislation pursuant\nto the following:\nArticle 1, Section 8\nThe single subject of this legislation is:\nAviation Safety\n[Page H1181]\n</pre>",
#     "cosponsors": {
#       "count": 3,
#       "countIncludingWithdrawnCosponsors": 3,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/cosponsors?format=json"
#     },
#     "introducedDate": "2024-03-13",
#     "latestAction": {
#       "actionDate": "2024-03-13",
#       "text": "Referred to the House Committee on Transportation and Infrastructure."
#     },
#     "number": "7660",
#     "originChamber": "House",
#     "originChamberCode": "H",
#     "policyArea": {
#       "name": "Transportation and Public Works"
#     },
#     "relatedBills": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/relatedbills?format=json"
#     },
#     "sponsors": [
#       {
#         "bioguideId": "H001096",
#         "firstName": "Harriet",
#         "fullName": "Rep. Hageman, Harriet M. [R-WY-At Large]",
#         "isByRequest": "N",
#         "lastName": "Hageman",
#         "middleName": "M.",
#         "party": "R",
#         "state": "WY",
#         "url": "https://api.congress.gov/v3/member/H001096?format=json"
#       }
#     ],
#     "subjects": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/subjects?format=json"
#     },
#     "textVersions": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/text?format=json"
#     },
#     "title": "Backcountry Aviation Protection Act",
#     "titles": {
#       "count": 3,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7660/titles?format=json"
#     },
#     "type": "HR",
#     "updateDate": "2024-03-22T14:15:50Z",
#     "updateDateIncludingText": "2024-03-22T14:15:50Z"
#   },
#   "request": {
#     "billNumber": "7660",
#     "billType": "hr",
#     "congress": "118",
#     "contentType": "application/json",
#     "format": "json"
#   }
# }
# {
#   "congress": 118,
#   "latestAction": {
#     "actionDate": "2024-03-01",
#     "text": "Referred to the Committee on Homeland Security, and in addition to the Committee on Transportation and Infrastructure, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned."
#   },
#   "number": "7519",
#   "originChamber": "House",
#   "originChamberCode": "H",
#   "title": "To authorize a temporary increase in the permitted use of certain homeland security grants, and for other purposes.",
#   "type": "HR",
#   "updateDate": "2024-03-18",
#   "updateDateIncludingText": "2024-03-18T22:21:33Z",
#   "url": "https://api.congress.gov/v3/bill/118/hr/7519?format=json"
# }
# {
#   "bill": {
#     "actions": {
#       "count": 4,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7519/actions?format=json"
#     },
#     "committees": {
#       "count": 2,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7519/committees?format=json"
#     },
#     "congress": 118,
#     "constitutionalAuthorityStatementText": "<pre>\n[Congressional Record Volume 170, Number 38 (Friday, March 1, 2024)]\n[House]\nFrom the Congressional Record Online through the Government Publishing Office [<a href=\"https://www.gpo.gov\">www.gpo.gov</a>]\nBy Mr. SCHWEIKERT:\nH.R. 7519.\nCongress has the power to enact this legislation pursuant\nto the following:\nClause 18 of Section 8 of Article I of the Consititution:\n[The Congress shall have Power . . .] To make all Laws which\nshall be necessary and proper for carrying into Execution the\nforegoing Powers, and all other Powers vested by this\nConstitution in the Government of the United States, or in\nany Department or Officer thereof.\nThe single subject of this legislation is:\nTo authorize a temporary increase in the permitted use of\ncertain homeland security grants.\n[Page H781]\n</pre>",
#     "introducedDate": "2024-03-01",
#     "latestAction": {
#       "actionDate": "2024-03-01",
#       "text": "Referred to the Committee on Homeland Security, and in addition to the Committee on Transportation and Infrastructure, for a period to be subsequently determined by the Speaker, in each case for consideration of such provisions as fall within the jurisdiction of the committee concerned."
#     },
#     "number": "7519",
#     "originChamber": "House",
#     "originChamberCode": "H",
#     "policyArea": {
#       "name": "Government Operations and Politics"
#     },
#     "sponsors": [
#       {
#         "bioguideId": "S001183",
#         "district": 1,
#         "firstName": "David",
#         "fullName": "Rep. Schweikert, David [R-AZ-1]",
#         "isByRequest": "N",
#         "lastName": "Schweikert",
#         "party": "R",
#         "state": "AZ",
#         "url": "https://api.congress.gov/v3/member/S001183?format=json"
#       }
#     ],
#     "subjects": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7519/subjects?format=json"
#     },
#     "textVersions": {
#       "count": 1,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7519/text?format=json"
#     },
#     "title": "To authorize a temporary increase in the permitted use of certain homeland security grants, and for other purposes.",
#     "titles": {
#       "count": 2,
#       "url": "https://api.congress.gov/v3/bill/118/hr/7519/titles?format=json"
#     },
#     "type": "HR",
#     "updateDate": "2024-03-18T22:21:33Z",
#     "updateDateIncludingText": "2024-03-18T22:21:33Z"
#   },
#   "request": {
#     "billNumber": "7519",
#     "billType": "hr",
#     "congress": "118",
#     "contentType": "application/json",
#     "format": "json"
#   }
# }
#      congress latestAction_actionDate  \
# 0         118              2024-03-13
# 1         118              2024-03-13
# 2         118              2024-03-13
# 3         118              2024-03-13
# 4         118              2024-03-13
# ..        ...                     ...
# 245       118              2024-03-01
# 246       118              2024-03-01
# 247       118              2024-03-01
# 248       118              2024-03-01
# 249       118              2024-03-01
#
#                                      latestAction_text number originChamber  \
# 0    Referred to the House Committee on Transportat...   7660         House
# 1    Referred to the Committee on Energy and Commer...   7675         House
# 2    Referred to the House Committee on the Judiciary.   7676         House
# 3    Referred to the House Committee on Transportat...   7671         House
# 4    Referred to the House Committee on Ways and Me...   7664         House
# ..                                                 ...    ...           ...
# 245  Referred to the House Committee on Ways and Me...   7517         House
# 246  Referred to the Committee on Natural Resources...   7516         House
# 247  Referred to the House Committee on Financial S...   7515         House
# 248  Referred to the House Committee on Veterans' A...   7514         House
# 249  Referred to the Committee on Homeland Security...   7519         House
#
#     originChamberCode                                              title type  \
# 0                   H                Backcountry Aviation Protection Act   HR
# 1                   H  To extend the authorization of appropriations ...   HR
# 2                   H  To amend title 18, United States Code, to proh...   HR
# 3                   H        Disaster Management Costs Modernization Act   HR
# 4                   H             21st Century Children and Families Act   HR
# ..                ...                                                ...  ...
# 245                 H  To amend the Internal Revenue Code of 1986 to ...   HR
# 246                 H  Purchased and Referred Care Improvement Act of...   HR
# 247                 H    Protecting Native Americans’ Credit Act of 2024   HR
# 248                 H                                         WAIVER Act   HR
# 249                 H  To authorize a temporary increase in the permi...   HR
#
#      updateDate updateDateIncludingText  \
# 0    2024-03-22    2024-03-22T14:15:50Z
# 1    2024-03-18    2024-03-18T22:28:45Z
# 2    2024-03-28    2024-03-28T04:20:24Z
# 3    2024-03-28    2024-03-28T05:00:30Z
# 4    2024-03-22    2024-03-22T03:45:48Z
# ..          ...                     ...
# 245  2024-03-18    2024-03-18T22:21:26Z
# 246  2024-03-27    2024-03-27T19:45:34Z
# 247  2024-03-18    2024-03-18T22:22:46Z
# 248  2024-03-22    2024-03-22T04:05:32Z
# 249  2024-03-18    2024-03-18T22:21:33Z
#
#                                                    url latestAction_actionTime
# 0    https://api.congress.gov/v3/bill/118/hr/7660?f...                     NaN
# 1    https://api.congress.gov/v3/bill/118/hr/7675?f...                     NaN
# 2    https://api.congress.gov/v3/bill/118/hr/7676?f...                     NaN
# 3    https://api.congress.gov/v3/bill/118/hr/7671?f...                     NaN
# 4    https://api.congress.gov/v3/bill/118/hr/7664?f...                     NaN
# ..                                                 ...                     ...
# 245  https://api.congress.gov/v3/bill/118/hr/7517?f...                     NaN
# 246  https://api.congress.gov/v3/bill/118/hr/7516?f...                     NaN
# 247  https://api.congress.gov/v3/bill/118/hr/7515?f...                     NaN
# 248  https://api.congress.gov/v3/bill/118/hr/7514?f...                     NaN
# 249  https://api.congress.gov/v3/bill/118/hr/7519?f...                     NaN
#
# [250 rows x 12 columns]

# %% [markdown]
# ### List of actions

# %%
r=requests.get(
    "https://api.congress.gov/v3/bill/118/s/3427/actions?format=json",
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={
        "limit": 250,
        "format": "json",
        "offset": 0
    }
)
#print(json.dumps(r.json(),indent=2))
df = pd.DataFrame(r.json()["actions"])
display(df)
# Out:
#    actionCode  actionDate                                sourceSystem  \
# 0      E40000  2024-02-06  {'code': 9, 'name': 'Library of Congress'}
# 1       36000  2024-02-06  {'code': 9, 'name': 'Library of Congress'}
# 2      E30000  2024-02-06  {'code': 9, 'name': 'Library of Congress'}
# 3      E20000  2024-01-31  {'code': 2, 'name': 'House floor actions'}
# 4      E20000  2024-01-31  {'code': 2, 'name': 'House floor actions'}
# 5       28000  2024-01-31  {'code': 9, 'name': 'Library of Congress'}
# 6       28000  2024-01-31  {'code': 9, 'name': 'Library of Congress'}
# 7      H38310  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 8      H38310  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 9      H37300  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 10     H37300  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 11       8000  2024-01-29  {'code': 9, 'name': 'Library of Congress'}
# 12       8000  2024-01-29  {'code': 9, 'name': 'Library of Congress'}
# 13     H30000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 14     H30000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 15     H37220  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 16     H37220  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 17     H8D000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 18     H8D000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 19     H30000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 20     H30000  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 21     H30300  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 22     H30300  2024-01-29  {'code': 2, 'name': 'House floor actions'}
# 23     H15000  2023-12-22  {'code': 2, 'name': 'House floor actions'}
# 24     H14000  2023-12-22  {'code': 2, 'name': 'House floor actions'}
# 25        NaN  2023-12-20                          {'name': 'Senate'}
# 26        NaN  2023-12-18                          {'name': 'Senate'}
# 27      17000  2023-12-18  {'code': 9, 'name': 'Library of Congress'}
# 28        NaN  2023-12-18                          {'name': 'Senate'}
# 29      14500  2023-12-18  {'code': 9, 'name': 'Library of Congress'}
# 30        NaN  2023-12-06                          {'name': 'Senate'}
# 31      10000  2023-12-06  {'code': 9, 'name': 'Library of Congress'}
#
#                                                  text           type  \
# 0                       Became Public Law No: 118-38.      President
# 1                       Became Public Law No: 118-38.      BecameLaw
# 2                                Signed by President.      President
# 3                             Presented to President.          Floor
# 4                             Presented to President.          Floor
# 5                             Presented to President.      President
# 6                             Presented to President.      President
# 7   Motion to reconsider laid on the table Agreed ...          Floor
# 8   Motion to reconsider laid on the table Agreed ...          Floor
# 9   On motion to suspend the rules and pass the bi...          Floor
# 10  On motion to suspend the rules and pass the bi...          Floor
# 11  Passed/agreed to in House On motion to suspend...          Floor
# 12  Passed/agreed to in House On motion to suspend...          Floor
# 13  Considered as unfinished business. (considerat...          Floor
# 14                 Considered as unfinished business.          Floor
# 15  At the conclusion of debate, the Yeas and Nays...          Floor
# 16  At the conclusion of debate, the Yeas and Nays...          Floor
# 17  DEBATE - The House proceeded with forty minute...          Floor
# 18  DEBATE - The House proceeded with forty minute...          Floor
# 19  Considered under suspension of the rules. (con...          Floor
# 20          Considered under suspension of the rules.          Floor
# 21  Mr. Donalds moved to suspend the rules and pas...          Floor
# 22  Mr. Donalds moved to suspend the rules and pas...          Floor
# 23                                  Held at the desk.          Floor
# 24                             Received in the House.          Floor
# 25        Message on Senate action sent to the House.          Floor
# 26  Passed Senate without amendment by Unanimous C...          Floor
# 27  Passed/agreed to in Senate: Passed Senate with...          Floor
# 28  Senate Committee on the Judiciary discharged b...      Discharge
# 29  Senate Committee on the Judiciary discharged b...      Committee
# 30  Read twice and referred to the Committee on th...  IntroReferral
# 31                               Introduced in Senate  IntroReferral
#
#    actionTime                                      recordedVotes  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# 5         NaN                                                NaN
# 6         NaN                                                NaN
# 7    19:07:25                                                NaN
# 8    19:07:25                                                NaN
# 9    19:07:24  [{'chamber': 'House', 'congress': 118, 'date':...
# 10   19:07:24  [{'chamber': 'House', 'congress': 118, 'date':...
# 11   19:07:24  [{'chamber': 'House', 'congress': 118, 'date':...
# 12   19:07:24  [{'chamber': 'House', 'congress': 118, 'date':...
# 13   18:59:08                                                NaN
# 14   18:59:08                                                NaN
# 15   16:13:50                                                NaN
# 16   16:13:50                                                NaN
# 17   16:08:05                                                NaN
# 18   16:08:05                                                NaN
# 19   16:08:03                                                NaN
# 20   16:08:03                                                NaN
# 21   16:07:31                                                NaN
# 22   16:07:31                                                NaN
# 23   09:17:40                                                NaN
# 24   09:13:10                                                NaN
# 25        NaN                                                NaN
# 26        NaN                                                NaN
# 27        NaN                                                NaN
# 28        NaN                                                NaN
# 29        NaN                                                NaN
# 30        NaN                                                NaN
# 31        NaN                                                NaN
#
#                                            committees
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  [{'name': 'Judiciary Committee', 'systemCode':...
# 29  [{'name': 'Judiciary Committee', 'systemCode':...
# 30  [{'name': 'Judiciary Committee', 'systemCode':...
# 31                                                NaN

# %% [markdown]
# ### List of Congress Members

# %%
members=list()
url= "https://api.congress.gov/v3/member"
params={
    "limit": 250,
    "format": "json",
    "offset": 0
}
done = False
while not done:
  r=requests.get(
      url,
      headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
      params=params
  )
  #print(json.dumps(r.json(),indent=2))
  members.extend(r.json()["members"])
  pagination=r.json()["pagination"]
  #print(pagination)
  if "next" in pagination:
    purl=urlparse(pagination["next"])
    url = purl.scheme + "://" + purl.netloc + purl.path
    params = parse_qs(purl.query)
    #print(url)
    #print(params)
  else:
    done=True
    break
df=pd.DataFrame(members)
display(df)
# Out:
#      bioguideId                                          depiction  district  \
# 0       M001165  {'attribution': 'Image courtesy of the Member'...      20.0
# 1       B001297  {'attribution': 'Congressional Pictorial Direc...       4.0
# 2       J000292  {'attribution': 'Image courtesy of the Member'...       6.0
# 3       H001038  {'attribution': 'Image, Congressional Pictoria...      26.0
# 4       S001176  {'attribution': 'Image courtesy of the Member'...       1.0
# ...         ...                                                ...       ...
# 2513    F000229  {'attribution': 'Collection of the U.S. House ...       6.0
# 2514    F000218  {'attribution': 'Collection of the U.S. House ...       7.0
# 2515    F000215  {'attribution': 'Collection of the U.S. House ...       1.0
# 2516    F000209  {'attribution': 'Collection of the U.S. House ...      11.0
# 2517    F000208  {'attribution': 'Collection of the U.S. House ...       5.0
#
#                      name   partyName         state  \
# 0         McCarthy, Kevin  Republican    California
# 1               Buck, Ken  Republican      Colorado
# 2           Johnson, Bill  Republican          Ohio
# 3          Higgins, Brian  Democratic      New York
# 4          Scalise, Steve  Republican     Louisiana
# ...                   ...         ...           ...
# 2513  Flynt, John J., Jr.  Democratic       Georgia
# 2514      Flowers, Walter  Democratic       Alabama
# 2515     Florio, James J.  Democratic    New Jersey
# 2516     Flood, Daniel J.  Democratic  Pennsylvania
# 2517    Flippo, Ronnie G.  Democratic       Alabama
#
#                                                   terms            updateDate  \
# 0     {'item': [{'chamber': 'House of Representative...  2024-04-12T19:59:51Z
# 1     {'item': [{'chamber': 'House of Representative...  2024-04-12T19:59:48Z
# 2     {'item': [{'chamber': 'House of Representative...  2024-04-12T19:59:48Z
# 3     {'item': [{'chamber': 'House of Representative...  2024-04-12T19:59:48Z
# 4     {'item': [{'chamber': 'House of Representative...  2024-04-11T19:56:40Z
# ...                                                 ...                   ...
# 2513  {'item': [{'chamber': 'House of Representative...  2022-12-16T21:56:51Z
# 2514  {'item': [{'chamber': 'House of Representative...  2022-12-16T21:56:51Z
# 2515  {'item': [{'chamber': 'House of Representative...  2022-12-16T21:56:51Z
# 2516  {'item': [{'chamber': 'House of Representative...  2022-12-16T21:56:51Z
# 2517  {'item': [{'chamber': 'House of Representative...  2022-12-16T21:56:51Z
#
#                                                     url
# 0     https://api.congress.gov/v3/member/M001165?for...
# 1     https://api.congress.gov/v3/member/B001297?for...
# 2     https://api.congress.gov/v3/member/J000292?for...
# 3     https://api.congress.gov/v3/member/H001038?for...
# 4     https://api.congress.gov/v3/member/S001176?for...
# ...                                                 ...
# 2513  https://api.congress.gov/v3/member/F000229?for...
# 2514  https://api.congress.gov/v3/member/F000218?for...
# 2515  https://api.congress.gov/v3/member/F000215?for...
# 2516  https://api.congress.gov/v3/member/F000209?for...
# 2517  https://api.congress.gov/v3/member/F000208?for...
#
# [2518 rows x 9 columns]

# %%
# Get Data

bio_df = df[["bioguideId","name","partyName","state"]]
display(bio_df)
json.dump(json.loads(bio_df.to_json(orient='records')),open(f'{DATA_FOLDER}/all_bios.json','w'),indent=2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      bioguideId                 name   partyName         state
# 0       M001165      McCarthy, Kevin  Republican    California
# 1       B001297            Buck, Ken  Republican      Colorado
# 2       J000292        Johnson, Bill  Republican          Ohio
# 3       H001038       Higgins, Brian  Democratic      New York
# 4       S001176       Scalise, Steve  Republican     Louisiana
# ...         ...                  ...         ...           ...
# 2513    F000229  Flynt, John J., Jr.  Democratic       Georgia
# 2514    F000218      Flowers, Walter  Democratic       Alabama
# 2515    F000215     Florio, James J.  Democratic    New Jersey
# 2516    F000209     Flood, Daniel J.  Democratic  Pennsylvania
# 2517    F000208    Flippo, Ronnie G.  Democratic       Alabama
#
# [2518 rows x 4 columns]

# %%
def extended_describe(df):
  info_df = df.describe(include="all").T
  info_df['Data Type'] = df.dtypes
  info_df['Non-Null Count'] = df.notnull().sum()
  info_df['Null Count'] = df.isnull().sum()
  info_df['Null Percentage'] = ((info_df['Null Count'] / len(df)) * 100).round(4)
  return info_df

display(extended_describe(bio_df))
bio_df.to_csv(f'{DATA_FOLDER}/all_bios.csv')
# Out:
#            count unique               top  freq Data Type  Non-Null Count  \
# bioguideId  2518   2518           M001165     1    object            2518
# name        2518   2515  Menendez, Robert     2    object            2518
# partyName   2518      5        Democratic  1263    object            2518
# state       2518     56        California   215    object            2518
#
#             Null Count  Null Percentage
# bioguideId           0              0.0
# name                 0              0.0
# partyName            0              0.0
# state                0              0.0

# %% [markdown]
# ### Sample Congressional Bio Information
#
# We will get the information and list the terms for James McGovern

# %%
r=requests.get(
    "https://api.congress.gov/v3/member/M000312",
    headers={ "X-Api-Key": "n2XVSgBBDPaeN4M5mJjkg7plDqfaP5HgDodQsFHK"},
    params={
        "format": "json"
    }
)
#print(json.dumps(r.json()["terms"][0],indent=2))
df = pd.DataFrame(r.json()["member"]["terms"])
display(df)
# Out:
#                      chamber  congress  district  endYear      memberType  \
# 0   House of Representatives       105         3   1999.0  Representative
# 1   House of Representatives       106         3   2001.0  Representative
# 2   House of Representatives       107         3   2003.0  Representative
# 3   House of Representatives       108         3   2005.0  Representative
# 4   House of Representatives       109         3   2007.0  Representative
# 5   House of Representatives       110         3   2009.0  Representative
# 6   House of Representatives       111         3   2011.0  Representative
# 7   House of Representatives       112         3   2013.0  Representative
# 8   House of Representatives       113         2   2015.0  Representative
# 9   House of Representatives       114         2   2017.0  Representative
# 10  House of Representatives       115         2   2019.0  Representative
# 11  House of Representatives       116         2   2021.0  Representative
# 12  House of Representatives       117         2   2023.0  Representative
# 13  House of Representatives       118         2      NaN  Representative
#
#     startYear stateCode      stateName
# 0        1997        MA  Massachusetts
# 1        1999        MA  Massachusetts
# 2        2001        MA  Massachusetts
# 3        2003        MA  Massachusetts
# 4        2005        MA  Massachusetts
# 5        2007        MA  Massachusetts
# 6        2009        MA  Massachusetts
# 7        2011        MA  Massachusetts
# 8        2013        MA  Massachusetts
# 9        2015        MA  Massachusetts
# 10       2017        MA  Massachusetts
# 11       2019        MA  Massachusetts
# 12       2021        MA  Massachusetts
# 13       2023        MA  Massachusetts

# %% [markdown]
# ## Actions Analysis

# %%
bills = list()
actions = list()
for i in range (93,117):
    bills.extend(json.load(open(f'{DATA_FOLDER}/{i}.json')))

for bill in bills:
    congress=bill["congress"]
    if "actions" in bill:
        bill_actions = copy.deepcopy(bill["actions"])
        for action in bill_actions:
            action["congress"] = congress
        actions.extend(bill_actions)

df = pd.DataFrame(actions)
# Add a new column "congress" with the value of i for each bill

display(extended_describe(df))
# Out:
#                  count  unique                                       top  \
# action_date    1014993  113163                                1977-01-04
# action_text    1014993  149417  Sponsor introductory remarks on measure.
# action_type    1014993      12                                  referral
# action_status   320863      27                                  REFERRED
# action_code     200134     101
# congress       1014993      24                                       116
#
#                  freq Data Type  Non-Null Count  Null Count  Null Percentage
# action_date      1622    object         1014993           0           0.0000
# action_text     35511    object         1014993           0           0.0000
# action_type    454622    object         1014993           0           0.0000
# action_status  259167    object          320863      694130          68.3877
# action_code     66803    object          200134      814859          80.2822
# congress        54799    object         1014993           0           0.0000

# %%
display(extended_describe(df))


if False:
  display_markdown("## Unique Values of Key Action Fields",raw=True)
  for col in ["action_type","action_status"]:
    display_markdown(f'### {col}',raw=True)
    vals = df[col].unique()
    for val in vals:
      display_markdown(f'* {val}',raw=True)

action_map=list()
action_history=dict()
action_type_history=dict()
action_status_history=dict()
for i in range(93, 117):
  congress=str(i)
  #display_markdown(f"# Congress: {congress}", raw=True)
  #display_markdown("## Unique Values of Key Action Fields", raw=True)
  for col in ["action_type", "action_status"]:
      # display_markdown(f'### {col}', raw=True)
      counts = df[df["congress"]==congress][col].value_counts()
      for val, count in counts.items():
          # display_markdown(f'* {val}: {count}', raw=True)
          action_map.append({
              "congress": congress,
              "feature": col,
              "val": val,
              "count": count
          })
          val_id = f'{col[7]}_{val}'
          if not val_id in action_history:
            action_history[val_id]=dict()
          action_history[val_id][congress]=count
          if col == "action_type":
            if not val in action_type_history:
              action_type_history[val]=dict()
            action_type_history[val][congress]=count
          else:
            if not val in action_status_history:
              action_status_history[val]=dict()
            action_status_history[val][congress]=count

action_type_history_df = pd.DataFrame(action_type_history)
display(action_type_history_df)
action_status_history_df = pd.DataFrame(action_status_history)
display(action_status_history_df)
action_history_df = pd.DataFrame(action_history)
display(action_history_df)
action_map_df = pd.DataFrame(action_map)
display(action_map_df)

with pd.ExcelWriter(f'{DATA_FOLDER}/action_dictionary.xlsx') as writer:
    # Write each DataFrame to a separate sheet
    action_type_history_df.to_excel(writer, sheet_name='Action Type', index=True)
    action_status_history_df.to_excel(writer, sheet_name='Action Status', index=True)
display_markdown("## Action", raw=True)
display(df[df["action_type"] == 'action'])
display_markdown("## Calendar", raw=True)
display(df[df["action_type"] == 'calendar'])
# Out:
#                  count  unique                                       top  \
# action_date    1014993  113163                                1977-01-04
# action_text    1014993  149417  Sponsor introductory remarks on measure.
# action_type    1014993      12                                  referral
# action_status   320863      27                                  REFERRED
# action_code     200134     101
# congress       1014993      24                                       116
#
#                  freq Data Type  Non-Null Count  Null Count  Null Percentage
# action_date      1622    object         1014993           0           0.0000
# action_text     35511    object         1014993           0           0.0000
# action_type    454622    object         1014993           0           0.0000
# action_status  259167    object          320863      694130          68.3877
# action_code     66803    object          200134      814859          80.2822
# congress        54799    object         1014993           0           0.0000
#      referral  action  topresident  signed  vetoed  calendar    vote  enacted  \
# 93      22834    6645         1442     685    36.0       NaN     NaN      NaN
# 94      21837   11406         1397     659    33.0       NaN     NaN      NaN
# 95      21011   12203         1508     734    18.0       NaN     NaN      NaN
# 96      13925   10701         1324     650    12.0       NaN     NaN      NaN
# 97      18891   20449          852     411    14.0    2007.0  1313.0    413.0
# 98      17899   19817          998     477    21.0    2401.0  1544.0    479.0
# 99      17316   16403          807     385    18.0    1916.0  1367.0    387.0
# 100     18326   17004         1064     512    19.0    2314.0  1671.0    516.0
# 101     19135   25099          907     433    18.0    2867.0  1707.0    435.0
# 102     20298   22781          920     435    24.0    2574.0  1752.0    436.0
# 103     16939   23931          740     370     NaN    2303.0  1387.0    370.0
# 104     14420   20235          652     308    16.0    2150.0  1234.0    311.0
# 105     15506   18816          756     370     8.0    2213.0  1404.0    371.0
# 106     18082   21251         1141     558    12.0    2820.0  1900.0    558.0
# 107     17182   14884          700     350     NaN    2191.0  1281.0    350.0
# 108     17078   16541          952     476     NaN    2449.0  1628.0    476.0
# 109     20205   16184          932     465     1.0    2140.0  1561.0    465.0
# 110     21583   19070          898     438    11.0    3161.0  1746.0    442.0
# 111     19892   14243          734     366     1.0    2171.0  1388.0    366.0
# 112     21236   13541          272     272     NaN    1876.0   992.0    272.0
# 113     18158   20304          282     282     NaN    2139.0  1066.0    282.0
# 114     18741   23786          330     324     5.0    2708.0  1479.0    326.0
# 115     20449   25191          417     417     NaN    3307.0  1806.0    417.0
# 116     23679   25669          313     249     1.0    2497.0  1427.0    241.0
#
#      vote-aux  discharged  reported  hearings
# 93        NaN         NaN       NaN       NaN
# 94        NaN         NaN       NaN       NaN
# 95        NaN         NaN       NaN       NaN
# 96        NaN         NaN       NaN       NaN
# 97        3.0         2.0       NaN       NaN
# 98        2.0         NaN       NaN       NaN
# 99        4.0         1.0       NaN       NaN
# 100       9.0         NaN       NaN       NaN
# 101       7.0         NaN       NaN       NaN
# 102      11.0         2.0       NaN       NaN
# 103       2.0         NaN       NaN       NaN
# 104       5.0         NaN       NaN       NaN
# 105      12.0         NaN       NaN       NaN
# 106      10.0         NaN     248.0       NaN
# 107      11.0         NaN     495.0       NaN
# 108       8.0         NaN     514.0       NaN
# 109      21.0         NaN     439.0       NaN
# 110      31.0         NaN     688.0       NaN
# 111      25.0         NaN     486.0       NaN
# 112      25.0         NaN     312.0       NaN
# 113      29.0         NaN     366.0     514.0
# 114      39.0         NaN     482.0     611.0
# 115      18.0         NaN     575.0     485.0
# 116      22.0         NaN     449.0     252.0
# Warning: Total number of columns (27) exceeds max_columns (20). Falling back to pandas display.
#      REFERRED  PROV_KILL:VETO  VETOED:POCKET  REPORTED  ENACTED:SIGNED  \
# 93      21838            24.0           12.0       NaN             NaN
# 94      19608            33.0            NaN       NaN             NaN
# 95      17987            14.0            4.0       NaN             NaN
# 96      11647            10.0            2.0       NaN             NaN
# 97      10418             8.0            6.0    1120.0           411.0
# 98       9387             7.0           14.0    1358.0           477.0
# 99       8555            11.0            7.0    1078.0           385.0
# 100      8354             8.0           11.0    1242.0           513.0
# 101      9035            13.0            5.0    1405.0           435.0
# 102      9412            14.0           10.0    1174.0           435.0
# 103      7698             NaN            NaN    1040.0           370.0
# 104      6401            16.0            NaN     969.0           310.0
# 105      7374             8.0            NaN    1008.0           370.0
# 106      8755            11.0            1.0    1238.0           558.0
# 107      8805             NaN            NaN     944.0           350.0
# 108      8258             NaN            NaN    1153.0           476.0
# 109     10343             1.0            NaN    1058.0           465.0
# 110     10829            11.0            NaN    1485.0           438.0
# 111     10448             1.0            NaN    1019.0           366.0
# 112     10273             NaN            NaN     959.0           272.0
# 113      8742             NaN            NaN    1117.0           282.0
# 114      9923             5.0            NaN    1382.0           324.0
# 115     11110             NaN            NaN    1630.0           417.0
# 116     13967             1.0            NaN    1341.0           249.0
#
#      PASS_OVER:HOUSE  PASS_OVER:SENATE  PASSED:BILL  PASS_BACK:SENATE  \
# 93               NaN               NaN          NaN               NaN
# 94               NaN               NaN          NaN               NaN
# 95               NaN               NaN          NaN               NaN
# 96               NaN               NaN          NaN               NaN
# 97             409.0             332.0        292.0             126.0
# 98             573.0             331.0        304.0             164.0
# 99             550.0             270.0        255.0             162.0
# 100            679.0             303.0        324.0             209.0
# 101            589.0             334.0        457.0             198.0
# 102            612.0             367.0        459.0             164.0
# 103            511.0             258.0        383.0             133.0
# 104            484.0             228.0        332.0             103.0
# 105            527.0             308.0        370.0             102.0
# 106            709.0             376.0        572.0             141.0
# 107            565.0             215.0        356.0              94.0
# 108            618.0             381.0        480.0              86.0
# 109            616.0             336.0        468.0              74.0
# 110            943.0             212.0        440.0              86.0
# 111            721.0             172.0        357.0              86.0
# 112            491.0             147.0        268.0              52.0
# 113            583.0             152.0        281.0              33.0
# 114            825.0             196.0        346.0              62.0
# 115            998.0             261.0        426.0              79.0
# 116            776.0             261.0        324.0              38.0
#
#      PASS_BACK:HOUSE  ...  CONFERENCE:PASSED:HOUSE  \
# 93               NaN  ...                      NaN
# 94               NaN  ...                      NaN
# 95               NaN  ...                      NaN
# 96               NaN  ...                      NaN
# 97              76.0  ...                      NaN
# 98              96.0  ...                      NaN
# 99              76.0  ...                      NaN
# 100             95.0  ...                      NaN
# 101             31.0  ...                     63.0
# 102             35.0  ...                     61.0
# 103             25.0  ...                     51.0
# 104              7.0  ...                     42.0
# 105             25.0  ...                     33.0
# 106             29.0  ...                     42.0
# 107             10.0  ...                     31.0
# 108             16.0  ...                     33.0
# 109             18.0  ...                     24.0
# 110             17.0  ...                     11.0
# 111             12.0  ...                     10.0
# 112              8.0  ...                      7.0
# 113              7.0  ...                      3.0
# 114             26.0  ...                      7.0
# 115             25.0  ...                      3.0
# 116             22.0  ...                      2.0
#
#      PROV_KILL:SUSPENSIONFAILED  VETOED:OVERRIDE_FAIL_ORIGINATING:HOUSE  \
# 93                          NaN                                     NaN
# 94                          NaN                                     NaN
# 95                          NaN                                     NaN
# 96                          NaN                                     NaN
# 97                          NaN                                     NaN
# 98                          NaN                                     NaN
# 99                          NaN                                     NaN
# 100                         NaN                                     NaN
# 101                         5.0                                     5.0
# 102                        12.0                                     3.0
# 103                        10.0                                     NaN
# 104                        10.0                                     5.0
# 105                        17.0                                     NaN
# 106                        15.0                                     2.0
# 107                         7.0                                     NaN
# 108                        10.0                                     NaN
# 109                        18.0                                     1.0
# 110                        17.0                                     5.0
# 111                        26.0                                     1.0
# 112                        14.0                                     NaN
# 113                         5.0                                     NaN
# 114                         7.0                                     2.0
# 115                         8.0                                     NaN
# 116                         2.0                                     NaN
#
#      VETOED:OVERRIDE_PASS_OVER:HOUSE  FAIL:ORIGINATING:HOUSE  \
# 93                               NaN                     NaN
# 94                               NaN                     NaN
# 95                               NaN                     NaN
# 96                               NaN                     NaN
# 97                               NaN                     NaN
# 98                               NaN                     NaN
# 99                               NaN                     NaN
# 100                              NaN                     NaN
# 101                              2.0                     2.0
# 102                              2.0                     5.0
# 103                              NaN                     1.0
# 104                              2.0                     2.0
# 105                              2.0                     6.0
# 106                              1.0                     2.0
# 107                              NaN                     NaN
# 108                              NaN                     1.0
# 109                              NaN                     1.0
# 110                              4.0                     3.0
# 111                              NaN                     NaN
# 112                              NaN                     2.0
# 113                              NaN                     1.0
# 114                              NaN                     2.0
# 115                              NaN                     3.0
# 116                              1.0                     NaN
#
#      VETOED:OVERRIDE_FAIL_SECOND:HOUSE  PROV_KILL:PINGPONGFAIL  \
# 93                                 NaN                     NaN
# 94                                 NaN                     NaN
# 95                                 NaN                     NaN
# 96                                 NaN                     NaN
# 97                                 NaN                     NaN
# 98                                 NaN                     NaN
# 99                                 NaN                     NaN
# 100                                NaN                     NaN
# 101                                NaN                     NaN
# 102                                2.0                     1.0
# 103                                NaN                     NaN
# 104                                NaN                     NaN
# 105                                NaN                     NaN
# 106                                NaN                     2.0
# 107                                NaN                     NaN
# 108                                NaN                     NaN
# 109                                NaN                     NaN
# 110                                NaN                     NaN
# 111                                NaN                     1.0
# 112                                NaN                     1.0
# 113                                NaN                     NaN
# 114                                NaN                     NaN
# 115                                NaN                     NaN
# 116                                NaN                     NaN
#
#      FAIL:ORIGINATING:SENATE  FAIL:SECOND:HOUSE  ENACTED:TENDAYRULE
# 93                       NaN                NaN                 NaN
# 94                       NaN                NaN                 NaN
# 95                       NaN                NaN                 NaN
# 96                       NaN                NaN                 NaN
# 97                       NaN                NaN                 NaN
# 98                       NaN                NaN                 NaN
# 99                       NaN                NaN                 NaN
# 100                      NaN                NaN                 NaN
# 101                      NaN                NaN                 NaN
# 102                      NaN                NaN                 NaN
# 103                      NaN                NaN                 NaN
# 104                      1.0                NaN                 NaN
# 105                      NaN                NaN                 NaN
# 106                      NaN                NaN                 NaN
# 107                      NaN                NaN                 NaN
# 108                      1.0                NaN                 NaN
# 109                      NaN                1.0                 NaN
# 110                      1.0                NaN                 NaN
# 111                      NaN                NaN                 NaN
# 112                      2.0                NaN                 NaN
# 113                      1.0                NaN                 NaN
# 114                      NaN                NaN                 1.0
# 115                      NaN                NaN                 NaN
# 116                      NaN                NaN                 NaN
#
# [24 rows x 27 columns]
# Warning: Total number of columns (39) exceeds max_columns (20). Falling back to pandas display.
#      t_referral  t_action  t_topresident  t_signed  t_vetoed  s_REFERRED  \
# 93        22834      6645           1442       685      36.0       21838
# 94        21837     11406           1397       659      33.0       19608
# 95        21011     12203           1508       734      18.0       17987
# 96        13925     10701           1324       650      12.0       11647
# 97        18891     20449            852       411      14.0       10418
# 98        17899     19817            998       477      21.0        9387
# 99        17316     16403            807       385      18.0        8555
# 100       18326     17004           1064       512      19.0        8354
# 101       19135     25099            907       433      18.0        9035
# 102       20298     22781            920       435      24.0        9412
# 103       16939     23931            740       370       NaN        7698
# 104       14420     20235            652       308      16.0        6401
# 105       15506     18816            756       370       8.0        7374
# 106       18082     21251           1141       558      12.0        8755
# 107       17182     14884            700       350       NaN        8805
# 108       17078     16541            952       476       NaN        8258
# 109       20205     16184            932       465       1.0       10343
# 110       21583     19070            898       438      11.0       10829
# 111       19892     14243            734       366       1.0       10448
# 112       21236     13541            272       272       NaN       10273
# 113       18158     20304            282       282       NaN        8742
# 114       18741     23786            330       324       5.0        9923
# 115       20449     25191            417       417       NaN       11110
# 116       23679     25669            313       249       1.0       13967
#
#      s_PROV_KILL:VETO  s_VETOED:POCKET  t_calendar  t_vote  ...  \
# 93               24.0             12.0         NaN     NaN  ...
# 94               33.0              NaN         NaN     NaN  ...
# 95               14.0              4.0         NaN     NaN  ...
# 96               10.0              2.0         NaN     NaN  ...
# 97                8.0              6.0      2007.0  1313.0  ...
# 98                7.0             14.0      2401.0  1544.0  ...
# 99               11.0              7.0      1916.0  1367.0  ...
# 100               8.0             11.0      2314.0  1671.0  ...
# 101              13.0              5.0      2867.0  1707.0  ...
# 102              14.0             10.0      2574.0  1752.0  ...
# 103               NaN              NaN      2303.0  1387.0  ...
# 104              16.0              NaN      2150.0  1234.0  ...
# 105               8.0              NaN      2213.0  1404.0  ...
# 106              11.0              1.0      2820.0  1900.0  ...
# 107               NaN              NaN      2191.0  1281.0  ...
# 108               NaN              NaN      2449.0  1628.0  ...
# 109               1.0              NaN      2140.0  1561.0  ...
# 110              11.0              NaN      3161.0  1746.0  ...
# 111               1.0              NaN      2171.0  1388.0  ...
# 112               NaN              NaN      1876.0   992.0  ...
# 113               NaN              NaN      2139.0  1066.0  ...
# 114               5.0              NaN      2708.0  1479.0  ...
# 115               NaN              NaN      3307.0  1806.0  ...
# 116               1.0              NaN      2497.0  1427.0  ...
#
#      s_VETOED:OVERRIDE_FAIL_ORIGINATING:HOUSE  \
# 93                                        NaN
# 94                                        NaN
# 95                                        NaN
# 96                                        NaN
# 97                                        NaN
# 98                                        NaN
# 99                                        NaN
# 100                                       NaN
# 101                                       5.0
# 102                                       3.0
# 103                                       NaN
# 104                                       5.0
# 105                                       NaN
# 106                                       2.0
# 107                                       NaN
# 108                                       NaN
# 109                                       1.0
# 110                                       5.0
# 111                                       1.0
# 112                                       NaN
# 113                                       NaN
# 114                                       2.0
# 115                                       NaN
# 116                                       NaN
#
#      s_VETOED:OVERRIDE_PASS_OVER:HOUSE  s_FAIL:ORIGINATING:HOUSE  \
# 93                                 NaN                       NaN
# 94                                 NaN                       NaN
# 95                                 NaN                       NaN
# 96                                 NaN                       NaN
# 97                                 NaN                       NaN
# 98                                 NaN                       NaN
# 99                                 NaN                       NaN
# 100                                NaN                       NaN
# 101                                2.0                       2.0
# 102                                2.0                       5.0
# 103                                NaN                       1.0
# 104                                2.0                       2.0
# 105                                2.0                       6.0
# 106                                1.0                       2.0
# 107                                NaN                       NaN
# 108                                NaN                       1.0
# 109                                NaN                       1.0
# 110                                4.0                       3.0
# 111                                NaN                       NaN
# 112                                NaN                       2.0
# 113                                NaN                       1.0
# 114                                NaN                       2.0
# 115                                NaN                       3.0
# 116                                1.0                       NaN
#
#      s_VETOED:OVERRIDE_FAIL_SECOND:HOUSE  s_PROV_KILL:PINGPONGFAIL  \
# 93                                   NaN                       NaN
# 94                                   NaN                       NaN
# 95                                   NaN                       NaN
# 96                                   NaN                       NaN
# 97                                   NaN                       NaN
# 98                                   NaN                       NaN
# 99                                   NaN                       NaN
# 100                                  NaN                       NaN
# 101                                  NaN                       NaN
# 102                                  2.0                       1.0
# 103                                  NaN                       NaN
# 104                                  NaN                       NaN
# 105                                  NaN                       NaN
# 106                                  NaN                       2.0
# 107                                  NaN                       NaN
# 108                                  NaN                       NaN
# 109                                  NaN                       NaN
# 110                                  NaN                       NaN
# 111                                  NaN                       1.0
# 112                                  NaN                       1.0
# 113                                  NaN                       NaN
# 114                                  NaN                       NaN
# 115                                  NaN                       NaN
# 116                                  NaN                       NaN
#
#      s_FAIL:ORIGINATING:SENATE  t_reported  s_FAIL:SECOND:HOUSE  t_hearings  \
# 93                         NaN         NaN                  NaN         NaN
# 94                         NaN         NaN                  NaN         NaN
# 95                         NaN         NaN                  NaN         NaN
# 96                         NaN         NaN                  NaN         NaN
# 97                         NaN         NaN                  NaN         NaN
# 98                         NaN         NaN                  NaN         NaN
# 99                         NaN         NaN                  NaN         NaN
# 100                        NaN         NaN                  NaN         NaN
# 101                        NaN         NaN                  NaN         NaN
# 102                        NaN         NaN                  NaN         NaN
# 103                        NaN         NaN                  NaN         NaN
# 104                        1.0         NaN                  NaN         NaN
# 105                        NaN         NaN                  NaN         NaN
# 106                        NaN       248.0                  NaN         NaN
# 107                        NaN       495.0                  NaN         NaN
# 108                        1.0       514.0                  NaN         NaN
# 109                        NaN       439.0                  1.0         NaN
# 110                        1.0       688.0                  NaN         NaN
# 111                        NaN       486.0                  NaN         NaN
# 112                        2.0       312.0                  NaN         NaN
# 113                        1.0       366.0                  NaN       514.0
# 114                        NaN       482.0                  NaN       611.0
# 115                        NaN       575.0                  NaN       485.0
# 116                        NaN       449.0                  NaN       252.0
#
#      s_ENACTED:TENDAYRULE
# 93                    NaN
# 94                    NaN
# 95                    NaN
# 96                    NaN
# 97                    NaN
# 98                    NaN
# 99                    NaN
# 100                   NaN
# 101                   NaN
# 102                   NaN
# 103                   NaN
# 104                   NaN
# 105                   NaN
# 106                   NaN
# 107                   NaN
# 108                   NaN
# 109                   NaN
# 110                   NaN
# 111                   NaN
# 112                   NaN
# 113                   NaN
# 114                   1.0
# 115                   NaN
# 116                   NaN
#
# [24 rows x 39 columns]
#     congress        feature                              val  count
# 0         93    action_type                         referral  22834
# 1         93    action_type                           action   6645
# 2         93    action_type                      topresident   1442
# 3         93    action_type                           signed    685
# 4         93    action_type                           vetoed     36
# ..       ...            ...                              ...    ...
# 533      116  action_status          CONFERENCE:PASSED:HOUSE      2
# 534      116  action_status       PROV_KILL:SUSPENSIONFAILED      2
# 535      116  action_status                   PROV_KILL:VETO      1
# 536      116  action_status  VETOED:OVERRIDE_PASS_OVER:HOUSE      1
# 537      116  action_status               FAIL:SECOND:SENATE      1
#
# [538 rows x 4 columns]
# ## Action
# Warning: total number of rows (436154) exceeds max_rows (20000). Falling back to pandas display.
#         action_date                                        action_text  \
# 1        1974-10-09                              Ordered held at desk.
# 5        1974-05-15  Reported to Senate from the Committee on Labor...
# 6        1974-05-16  Measure indefinitely postponed in Senate (text...
# 8        1973-12-04  Reported to Senate from the Committee on Publi...
# 9        1973-12-17      Measure passed Senate, roll call #588 (85-0).
# ...             ...                                                ...
# 1014982  2020-10-01  Committee Consideration and Mark-up Session Held.
# 1014984  2020-03-05                                Introduced in House
# 1014987  2020-03-12  Subcommittee Consideration and Mark-up Session...
# 1014988  2020-03-12  Forwarded by Subcommittee to Full Committee by...
# 1014989  2019-09-24                                Introduced in House
#
#         action_type action_status action_code congress
# 1            action          None        None       93
# 5            action          None        None       93
# 6            action          None        None       93
# 8            action          None        None       93
# 9            action          None        None       93
# ...             ...           ...         ...      ...
# 1014982      action          None                  116
# 1014984      action          None     Intro-H      116
# 1014987      action          None                  116
# 1014988      action          None                  116
# 1014989      action          None     Intro-H      116
#
# [436154 rows x 6 columns]
# ## Calendar
# Warning: total number of rows (48204) exceeds max_rows (20000). Falling back to pandas display.
#         action_date                                        action_text  \
# 129071   1982-12-08  Committee on Judiciary. Ordered to be reported...
# 129073   1982-12-08  Placed on Senate Legislative Calendar under Re...
# 129106   1981-09-30  Committee on Energy and Natural Resources. Ord...
# 129108   1981-10-22  Placed on Senate Legislative Calendar under Re...
# 129119   1981-09-30  Committee on Energy and Natural Resources. Ord...
# ...             ...                                                ...
# 1014870  2020-09-01    Placed on the Union Calendar, Calendar No. 386.
# 1014935  2019-01-28  Read the second time. Placed on Senate Legisla...
# 1014955  2019-09-25              Ordered to be Reported by Voice Vote.
# 1014957  2019-10-17    Placed on the Union Calendar, Calendar No. 190.
# 1014983  2020-10-01    Ordered to be Reported (Amended) by Voice Vote.
#
#         action_type action_status action_code congress
# 129071     calendar      REPORTED        None       97
# 129073     calendar          None        None       97
# 129106     calendar      REPORTED        None       97
# 129108     calendar          None        None       97
# 129119     calendar      REPORTED        None       97
# ...             ...           ...         ...      ...
# 1014870    calendar          None      H12410      116
# 1014935    calendar          None                  116
# 1014955    calendar      REPORTED                  116
# 1014957    calendar          None      H12410      116
# 1014983    calendar      REPORTED                  116
#
# [48204 rows x 6 columns]

# %%
display_markdown("## Unique", raw=True)

# Filter the DataFrame and select desired columns
df_filtered = df[df["action_type"] == 'action'][['action_text', 'action_status', 'action_code']]

# Replace null values with empty strings
df_filtered.replace({np.nan: ''}, inplace=True)

# Concatenate all fields and create a new column
df_filtered['concatenated'] = df_filtered.apply(lambda row: '|'.join(row), axis=1)

display_markdown("### Action Status", raw=True)

counts=df_filtered['action_status'].value_counts()
for val, count in counts.items():
    display_markdown(f'* {val}: {count}', raw=True)

display_markdown("### Action Code", raw=True)
counts=df_filtered['action_code'].value_counts()
for val, count in counts.items():
    display_markdown(f'* {val}: {count}', raw=True)

display_markdown("### Action Text", raw=True)
counts=df_filtered['action_text'].value_counts()
icount = 0
for val, count in counts.items():
    icount+=1
    display_markdown(f'* {val}: {count}', raw=True)
    if icount > 55:
      break


display(df_filtered.drop_duplicates())
# Out:
# ## Unique
# ### Action Status
# * : 436153
# * ENACTED:TENDAYRULE: 1
# ### Action Code
# * : 355469
# * Intro-H: 28716
# * 10000: 15441
# * H8D000: 11121
# * H30000: 4839
# * H38310: 3365
# * H30300: 2834
# * H12200: 2691
# * B00100: 2430
# * H12300: 887
# * H14000: 860
# * H37220: 755
# * H1L210: 538
# * H15000: 471
# * H35000: 464
# * H36100: 352
# * H36110: 350
# * H1L220: 334
# * H8A000: 331
# * H32700: 272
# * H32050: 265
# * H32340: 256
# * H32341: 256
# * H38800: 255
# * H32020: 251
# * H32400: 248
# * H32600: 243
# * H30200: 239
# * H34400: 198
# * H41931: 191
# * H41800: 141
# * 1000: 102
# * H12100: 95
# * H40150: 79
# * H41400: 75
# * H1B000: 71
# * H40140: 64
# * H41610: 63
# * H37210: 61
# * H11210: 60
# * H38900: 49
# * H40110: 44
# * H12210: 29
# * H40142: 28
# * H11200: 20
# * H17000: 19
# * H25200: 19
# * H42831: 18
# * H40200: 17
# * H12440: 15
# * H42300: 14
# * H82000: 12
# * H81000: 11
# * H36800: 11
# * H32311: 10
# * H32310: 10
# * H36810: 9
# * H32500: 7
# * H36610: 6
# * H32350: 6
# * H40210: 5
# * H32351: 5
# * H40130: 5
# * 5500: 5
# * H40141: 4
# * H41541: 4
# * H40300: 4
# * H42411: 3
# * H36200: 3
# * H38300: 3
# * H36210: 3
# * H42410: 3
# * H36600: 3
# * H34200: 2
# * H30800: 2
# * 5000: 2
# * H43210: 1
# * H37300: 1
# * H40310: 1
# * H88000: 1
# * H43200: 1
# * H41540: 1
# * H41521: 1
# * H41520: 1
# * H43110: 1
# * E30000: 1
# * H29800: 1
# ### Action Text
# * Sponsor introductory remarks on measure.: 35511
# * Introduced in House: 28818
# * Introduced in Senate: 15441
# * Committee Consideration and Mark-up Session Held.: 15010
# * Motion to reconsider laid on the table Agreed to without objection.: 14326
# * Subcommittee Hearings Held.: 13964
# * Message on Senate action sent to the House.: 10571
# * Considered under suspension of the rules.: 9433
# * Subcommittee Consideration and Mark-up Session Held.: 7867
# * Considered as unfinished business.: 4242
# * Received in the House.: 4108
# * Measure laid before Senate by unanimous consent.: 3485
# * Considered by Senate.: 3096
# * Measure considered in House.: 3065
# * Measure considered in Senate.: 2861
# * Measure Signed in Senate.: 2460
# * Executive Comment Requested from Interior.: 2386
# * Forwarded by Subcommittee to Full Committee (Amended).: 2372
# * Executive Comment Requested from DOD.: 2328
# * DEBATE - The House proceeded with forty minutes of debate.: 2322
# * At the conclusion of debate, the Yeas and Nays were demanded and ordered. Pursuant to the provisions of clause 8, rule XX, the Chair announced that further proceedings on the motion would be postponed.: 1947
# * Held at the desk.: 1903
# * Received in the Senate.: 1882
# * The previous question was ordered pursuant to the rule.: 1782
# * Measure enrolled in Senate.: 1674
# * Measure enrolled in House.: 1674
# * Measure passed Senate.: 1529
# * Committee Hearings Held.: 1528
# * Executive Comment Requested from USDA.: 1500
# * Measure passed Senate, amended.: 1478
# * Called up by House Under Suspension of Rules.: 1454
# * Forwarded by Subcommittee to Full Committee.: 1348
# * Call of calendar in Senate.: 1300
# * The title of the measure was amended. Agreed to without objection.: 1245
# * Received in the Senate, read twice.: 1188
# * Measure passed House, amended.: 1184
# * Considered by unanimous consent.: 1085
# * The previous question was ordered without objection.: 1069
# * Measure passed House.: 1039
# * Measure called up under motion to suspend rules and pass in House.: 1033
# * The House resolved into Committee of the Whole House on the state of the Union for further consideration.: 1014
# * Measure called up by unanimous consent in Senate.: 894
# * Forwarded by Subcommittee to Full Committee (Amended) by Voice Vote.: 847
# * Introduced in the Senate. Read the first time. Placed on Senate Legislative Calendar under Read the First Time.: 801
# * The previous question on the motion to recommit with instructions was ordered without objection.: 791
# * Forwarded by Subcommittee to Full Committee by Voice Vote.: 766
# * Executive Comment Received from ITC.: 750
# * Indefinitely postponed by Senate by Unanimous Consent.: 725
# * Conference held.: 707
# * The House adopted the amendment in the nature of a substitute as agreed to by the Committee of the Whole House on the state of the Union.: 701
# * Measure called up by special rule in House.: 687
# * Called up by House by Unanimous Consent.: 684
# * Executive Comment Requested from Treasury, Commerce, ITC, USTR.: 675
# * Conference scheduled in Senate.: 666
# * Conferees agreed to file conference report.: 663
# * Conference scheduled in House.: 659
# Warning: total number of rows (119908) exceeds max_rows (20000). Falling back to pandas display.
#                                                action_text action_status  \
# 1                                    Ordered held at desk.
# 5        Reported to Senate from the Committee on Labor...
# 6        Measure indefinitely postponed in Senate (text...
# 8        Reported to Senate from the Committee on Publi...
# 9            Measure passed Senate, roll call #588 (85-0).
# ...                                                    ...           ...
# 1014926  DEBATE - The House proceeded with one hour of ...
# 1014929  DEBATE - The House proceeded with 10 minutes o...
# 1014931  On motion to recommit with instructions Failed...
# 1014956  Reported by the Committee on Small Business. H...
# 1014960  DEBATE - The House proceeded with forty minute...
#
#         action_code                                       concatenated
# 1                                              Ordered held at desk.||
# 5                    Reported to Senate from the Committee on Labor...
# 6                    Measure indefinitely postponed in Senate (text...
# 8                    Reported to Senate from the Committee on Publi...
# 9                      Measure passed Senate, roll call #588 (85-0).||
# ...             ...                                                ...
# 1014926      H8D000  DEBATE - The House proceeded with one hour of ...
# 1014929      H8D000  DEBATE - The House proceeded with 10 minutes o...
# 1014931      H36110  On motion to recommit with instructions Failed...
# 1014956      H12200  Reported by the Committee on Small Business. H...
# 1014960      H8D000  DEBATE - The House proceeded with forty minute...
#
# [119908 rows x 4 columns]
